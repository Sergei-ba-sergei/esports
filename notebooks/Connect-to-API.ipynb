# %% [markdown]
# # Overview
#
# The strategy for collecting data will be simple. Since it is already known that rating is a very good indicator of skill level, we will:
#
# - select the top 2000 acounts on the ranked ladder
# - identify games with these players in them
# - save this data to a database
#
# To do this we will need to connect to a few different endpoints to get the required data.
#
# (We will separately need a mapping file between Professional players and their account names for our labelled data)

# %% [markdown]
# ### Import some libraries & API-Keys

# %%
import requests
import json
import time
import pandas as pd

# %%
with open('creds.json') as api_creds:
    creds = json.load(api_creds)
    
# credentials are now stored in the variable creds['key_one']

# %%
def riot_api(api, api_key):
    
    # note - the api must specify all variables in it, 
    # so the path may need to be created outside of this function
    URL = 'https://' + api + "?api_key=" + api_key
    
    response = requests.get(URL)
    
    return response.json()

# %%
# first we need a list of the top players in the EUW region

region = "euw1.api.riotgames.com"
challenger_endpoint = "/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5/"
grandmaster_endpoint = "/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5/"
master_endpoint = "/lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5/"

# %%
challenger = riot_api(region + challenger_endpoint, creds['key_one'])

# looks good!
challenger['entries']
# Out:
# [{'summonerId': 'BUpbqiivzJcwwTE5K61m2EvesrfpjR-uywQ_bp51Q03oaj0',
#   'summonerName': 'motus vetiti',
#   'leaguePoints': 820,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'JmkODrIn4ql6MBWZBB8z2pAT8CXGGzvtFwE32VOq8kQPYxUT',
#   'summonerName': 'JDX7 Odi11',
#   'leaguePoints': 902,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 115,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ykmcXq_mFOKMZWMFtR1pdKiz3iL_SSjbxmWw3eaDn4F4GlE-KII7LRQtsA',
#   'summonerName': 'YOUNG TALENT',
#   'leaguePoints': 636,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BykFSgMA-hkbuPdF3AE63gvGZ6b4L77X_9T4-J8Ed2PNyQM',
#   'summonerName': 'TakeSet sama',
#   'leaguePoints': 575,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'C8j4KeNHsR4PoXSDDfQTsilH-q2LmeltSm3GIoZeKrU-pG8i',
#   'summonerName': 'ssimpli',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'amDqltQIitAoqm5lU8RWzOi53DdRbYLY1WVTrcalp9uchza0',
#   'summonerName': 'the pebble',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'C8geiL2bSEJUvZcNWgj5OMlQFl5OVMnf7d_2SQYqirnZjnc',
#   'summonerName': 'Bielefeld',
#   'leaguePoints': 661,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'cTvBXuTMWna1vtiCjo_cf6_fDAuJ3qSFpbmfWWBzx4bmjVRA',
#   'summonerName': 'call of power',
#   'leaguePoints': 700,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kQvMwc4Un9qN7PoFzq1EU00fGPcjGft1IyhP3oiM5nqrih4',
#   'summonerName': 'BiIly Kimber',
#   'leaguePoints': 549,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Qy8iX9A5FGLj_MFrIIv1UK3r-JuGWjbFNPPtdTCpHPB-8inV4OgtSOfHFA',
#   'summonerName': 'YXZ12345',
#   'leaguePoints': 576,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'yRc6e8FspfxT8cT-pfZxjycrJn2X4aqxI2pfKQ-85ITRaaq2ri68UmldWg',
#   'summonerName': 'EMENES',
#   'leaguePoints': 543,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GOISWmIXrI4zWFuDgKo3vA9o9wj7JaXuc1M5uP1GjRvQZ_0',
#   'summonerName': 'Maςaquiñø',
#   'leaguePoints': 555,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'a4wCLXmINkIhNKSa1tFBn9vzxSlON4v_4Y0Mwfm44xkpfy9qGerlDMUFmg',
#   'summonerName': 'Fleshy1',
#   'leaguePoints': 567,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'NsLwF6zk-fdXVPcceJuVfi7rUCkKgONIslZHtOshmNM_-L_BtsvO-d7bRA',
#   'summonerName': 'Truncapochas',
#   'leaguePoints': 688,
#   'rank': 'I',
#   'wins': 121,
#   'losses': 97,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dtp20vLNkB5_BtuaXd9A2kvsa-Z-515qgcr_4EhEQCq318A',
#   'summonerName': 'Eason Gaming ',
#   'leaguePoints': 1026,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5X62b3Wg1VodDwMN7G6cqHlnokTbweWmifEotmZg12NP0Qhd74GtI657lg',
#   'summonerName': 'GGorabakda',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'JkxZLRAHmoR74g9otkTfqHyMOqmpNpNEQvDsboXbzr-iX3fk',
#   'summonerName': 'Thebausffs',
#   'leaguePoints': 565,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '__uDfBDwgb0LL60IswWaumGXXzo6ZC-k9EDmSUQiTivq5gU',
#   'summonerName': 'THE CHREAK',
#   'leaguePoints': 571,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'uvDTM4HRKCOHpxPOO8As7gFmDREhsbh63a-djRKs9AxTmf4qx-7TQ50y1Q',
#   'summonerName': 'AIba Madalyon',
#   'leaguePoints': 660,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VlGIbjkrS1dfkeV_o_BX00Am5_ZlhLeUrUnjjzTrk02jY0o',
#   'summonerName': 'MSF Irrelevant',
#   'leaguePoints': 822,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '8VZlOT8yf6-k0MqSxKjN0RzFm8giPFRLqIvJxL2c60cv5ns',
#   'summonerName': 'Aítana Øcaña',
#   'leaguePoints': 628,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '80S5Z0G__umAiWFIUsJtphZnTdSs4J9PQl8kgszYxe8M8ow',
#   'summonerName': 'Ekko the Neeko',
#   'leaguePoints': 726,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'oG75iOV-keJ7XwWKxKxFqm4wb3xbgREe468e8CWEKatU-G8',
#   'summonerName': 'school phobia',
#   'leaguePoints': 969,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'pKxA5ASDWaGnSwTwNhMSiKuc3379zRQRBRU7AmPMqco_3J6B',
#   'summonerName': 'Augenringe',
#   'leaguePoints': 600,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qJs8_Ve-1_3vT7MtffbOWpkw-u-JE87myRb_LQpseHdn2-k',
#   'summonerName': 'xFlavour4youGirl',
#   'leaguePoints': 819,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fwAc6k59NhHfrnrVWKmq9Qw8oYH1uJkSi-DnjavbbvP87QuXBDelJAruxA',
#   'summonerName': 'TwTv rawrbenXD',
#   'leaguePoints': 811,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 119,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'UKX0K41jEIJSsP0WkDh1XfqvLMRZn2hJ-ovLSH5l4ieTsjA',
#   'summonerName': 'pve guy',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 129,
#   'losses': 115,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 's2PFXSmLff1I61OBCOwaEQdvpfxetgMm4aRiTkPdyjcQDq0',
#   'summonerName': 'KC Rekkles',
#   'leaguePoints': 837,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'KEXnewQWO7TPVv25S7oKaMzKBEVCPWe7lFQX4cJVTILA1eNl',
#   'summonerName': 'G2 Dream',
#   'leaguePoints': 778,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '8yEVMv9J3REd5c9qKYvNPA4aF4ZPhzcPdJYti50tEsHypuU',
#   'summonerName': 'Agurin',
#   'leaguePoints': 1171,
#   'rank': 'I',
#   'wins': 128,
#   'losses': 106,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9AoLnGzDSpJA7oFSokMf3Ddr1OKuq9upv69L96I1AGLyYg7L',
#   'summonerName': 'gdgd',
#   'leaguePoints': 561,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'RUw5mGVWE4kOu4RDpQVPRBwoqqKc1Viw0FE58Kgl70GlUa8',
#   'summonerName': 'A41G Relative',
#   'leaguePoints': 561,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'NiwN6UnBqi07F9agR6HsErS9Kdz0T8LzVPlxUZEdAOWbAmNb',
#   'summonerName': 'TWTVBioticZilean',
#   'leaguePoints': 811,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 112,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'hcdwMeApAJGewH6BykjrT8utguYpLRafhn_qWnAVRW52DNaK',
#   'summonerName': 'Foutriquet',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'XcyF_qMFgcY3J_a3xeML6UGQiYjZc9isFMoNSdfRzUWgsShV151BWyjORw',
#   'summonerName': 'dzc',
#   'leaguePoints': 737,
#   'rank': 'I',
#   'wins': 167,
#   'losses': 146,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'TxpTdpOlspxjwxcvhLwysSzs0xwc5bhVS3fgU6muKFe2vcvE',
#   'summonerName': 'TTV RinANB',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Ic-6Oz0O2qEEYl3xMj7bGFQ0Ii9bMRwsXksRiwc7ERmaxpU',
#   'summonerName': 'EG PEIWAN Sao',
#   'leaguePoints': 819,
#   'rank': 'I',
#   'wins': 143,
#   'losses': 123,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'LacL-faZUdaYidDUGj8RjNh1Ipe_gXyPtmA0bkCk-03SZKux',
#   'summonerName': 'Baby Tarz1',
#   'leaguePoints': 550,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'K7MvTur0hUSjApxHClAjmOK9mqjOFOj-ZyFP_J3XDdrSHj0',
#   'summonerName': 'Monsieur Oui',
#   'leaguePoints': 550,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uTLTFVHEGgGRMqNZXmIEtbvJlV96ui-ov-v-odWXIAF8OUfh',
#   'summonerName': 'ÀitchAre',
#   'leaguePoints': 706,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'F8RdLr01x1JKIgLW6HqIueiL2q6EvOpzoXVIW2YybTf0w7g',
#   'summonerName': 'GODZILLA66666666',
#   'leaguePoints': 714,
#   'rank': 'I',
#   'wins': 151,
#   'losses': 141,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'KcQoNqsjaduqCtj1sPjGIrysmo_y9D35YK6hg_uqB9SZUEQ',
#   'summonerName': 'Nartock',
#   'leaguePoints': 599,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dKTd8oyGFtRiUybgNyaBCijKLNb1yYZm7JAz-xkeubPOU8s',
#   'summonerName': 'SlNGED',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'p4FKNr4ZqCtiOIqbEn5kPWeIi00JixLjFJA-Mb9kz1MFdqY',
#   'summonerName': 'Don Noway',
#   'leaguePoints': 1067,
#   'rank': 'I',
#   'wins': 138,
#   'losses': 115,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'VYD7lkK225NNFXnlZSQiowK9TyxDSDnvyvtqFb3mNLuRy83n',
#   'summonerName': 'devil gecko',
#   'leaguePoints': 757,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'CXcWmMQbg0iqzlxo-smfAKFEY_kO2GBqEzZ3yUIyblYe7cN5Jbtp9wXUwQ',
#   'summonerName': 'NOBREAK999999999',
#   'leaguePoints': 769,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'FY3nULJAQ3qH9jnMmLFuHw_EOMNUlIqrR2_8go-FN5H4ttSG',
#   'summonerName': 'golem of glory',
#   'leaguePoints': 557,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ieQ2-LrV4-mqR8LHB6gtiNlDlw2lROaGCBVCzkpUuJm7Je8xuTT5Qt-J2A',
#   'summonerName': 'Sunflοwer',
#   'leaguePoints': 1158,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 96,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fhxJhLpY_ioShZZWpJJTeHLXN4clezBAWV1mCS1QmwiG2FY',
#   'summonerName': 'POOPY PANTIES xD',
#   'leaguePoints': 625,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'J8NcsYG_yfdado7SwfvO2LZOtXQjozLKxG9DtN6FHcX_JmA',
#   'summonerName': 'Thebigestnoob1',
#   'leaguePoints': 676,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'BAo8ZgSkdxhYfbdOf33cu8XFBQGrWC3NOdMzkwp7MsU0FNg',
#   'summonerName': '2022mvp',
#   'leaguePoints': 1239,
#   'rank': 'I',
#   'wins': 129,
#   'losses': 96,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'RorrufXwg8gZaxQ-iMGiBcA8MI7HW-X-ykx-y3YjgL3JJas',
#   'summonerName': 'Iκιωι',
#   'leaguePoints': 603,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_YPssODQvpAWjBu7_Y-8DesU1lKhzOas0qVO4ze0YrMPlDOe',
#   'summonerName': 'AF Nano',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 125,
#   'losses': 110,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-d9BIf8pJ17W0tLMVh7uRNVnvQ7GU5F1gMRCHqcoLB_-8hQ-',
#   'summonerName': 'zta',
#   'leaguePoints': 913,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'QUNeBPbQR-t1hmMoZ0v5NVdo1jYVyTR782JU4qGS1S2rDV5H',
#   'summonerName': 'BJK Jeyrus',
#   'leaguePoints': 692,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'DmQtWMewndUmE0lH6yOrXvk-09fURvEFtaCRJSEb5QDvhxo8',
#   'summonerName': 'SMB Neramin',
#   'leaguePoints': 822,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'tbkJhRnb1l2l9TbvwAAkBcZ8BalnaJvbO5YqpOmiNmxtlVo',
#   'summonerName': 'KC Hantera1',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '43p_QncwD80tnDq5G3Egm6Rh_HYDEFcFipW0G3aYNqvdL72O',
#   'summonerName': 'huntiandi1',
#   'leaguePoints': 760,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '85YrrILIsDPn7p8NSYIM15f5qaIox1Ec9_KvQLs60YWlPvA',
#   'summonerName': 'Skream Takeover',
#   'leaguePoints': 735,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'iMGfBzxkodN9x9yoqgVHV_o2wCDVt6yW2OylDazZ8JHeL_E',
#   'summonerName': 'silkysmath',
#   'leaguePoints': 627,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'qZ8dTNWtDMid5xPZ1zUpxBrN_iBjFkhUUMPnI-ghLab_mIxL',
#   'summonerName': 'BJK Lot',
#   'leaguePoints': 697,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Tg1FSzUFs6n_fdk2PKsGbjPS94f9hwm-192vU-ZmHV9rV-8',
#   'summonerName': 'Katare',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GQb8dh7h7ITZBL5jQYv6CSzmnD0AneUZ3oLQnOWOQ3CFRr0',
#   'summonerName': 'EDEN F0X',
#   'leaguePoints': 554,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ZNz_Gnu0VyBCnfhZF4KBWdab0x_DwLsd7YepU4yKzPVdgks',
#   'summonerName': 'Jae',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 157,
#   'losses': 142,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'L5wsPtzgSUGAGlSMN1suSixl1QuoizsZ8pwPEjPo0V0XBLA',
#   'summonerName': 'CaÞs',
#   'leaguePoints': 1012,
#   'rank': 'I',
#   'wins': 124,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'rXybYkeOklmco3OoigqEKtHgMKIqDhDrk22CJ6EqOM73W48',
#   'summonerName': 'Spirgius',
#   'leaguePoints': 540,
#   'rank': 'I',
#   'wins': 146,
#   'losses': 130,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iRdTiWWLFW_Gi5qGbbzFix8u7vJzkkuv2ZX8Ochuf3S4PNuyDMTD3x2cAg',
#   'summonerName': 'SPOLFCEI',
#   'leaguePoints': 643,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'hhc1eL5HtK8i_FHOJV81kUjpL5n1B1UbVkv_jsf_GUb1uYyzh616yTTz5A',
#   'summonerName': 'Þyke Mid',
#   'leaguePoints': 716,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lJNy7dWHmpsA0G8iV2SRopFjlKl8vwP1Rq60ninTPP6LF1M',
#   'summonerName': 'foukinha gostosa',
#   'leaguePoints': 549,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'g7gGlvfQ-9oW53bdtD4HlsS0I5kqZr-kwY86hApjrf6-I6Q',
#   'summonerName': 'Elite500',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'z2Ye894uNOlekhM09G68q7Uxi4BvBJlBHtP4gHphnpGbPJw7',
#   'summonerName': 'zz why 3lue',
#   'leaguePoints': 812,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YfpLfCLHBWDZU1HeCaewq2YD4BOjmF1ZygQSNvh7hPoZX8Q',
#   'summonerName': 'HIVE Addusto',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'a67TuII-b07H_8jXsy7bqZAk9sIseglwS5gAXnVZL2g23z95TH1tVXAkBA',
#   'summonerName': 'Bagdiamond',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'U-tTZQKr8Jrgg-WUUKGIiFLWk6INBaVDQkIO3QmruMzclwdI',
#   'summonerName': 'Haze 8D',
#   'leaguePoints': 569,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 117,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YlZHQ4xjjpfgyHoXohaQfbdWda_MdLYyO8Ll5q8o2YGfFFo',
#   'summonerName': 'GTZ Pan',
#   'leaguePoints': 737,
#   'rank': 'I',
#   'wins': 120,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'y8ZnHOwvhUY20XvIcstjmvjNhq_GzSW4Zt-VmxEfGdmgMMcx',
#   'summonerName': 'BLU 113',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Sbrwfw2jD6ZSB8y4c-STwdSUNZJXMGhWLZRV2lJJhnF5rfTzadTbQ1NxhA',
#   'summonerName': 'RRubyLOL',
#   'leaguePoints': 828,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 94,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'nWmBpMRHkk_dnUTAwL4Cxs4xfushNraGwJkIFlLO1WXGmU98',
#   'summonerName': 'IW Serin',
#   'leaguePoints': 957,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '-Hqcl-CDz6GgOJN0efkKDAmJsQf9hF86psOkpkwx0GGUSm2Q',
#   'summonerName': 'ATTDÏ',
#   'leaguePoints': 541,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'j13oSank1UwR4lUqMBebVOiB3FF0XgypWB68k5MNvMZAipkK',
#   'summonerName': 'Sorya',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'EtbJotI-yaZ8I-UT2ViWkxleFKjJFWXwIOab2ezD3c-DgUE',
#   'summonerName': 'AHäHäCiK',
#   'leaguePoints': 802,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ZkABBSF4kPNpW2PVeUZ6C6UvMhaI82umMt1l3BEW_NxWZmo',
#   'summonerName': 'VE MetroArcher',
#   'leaguePoints': 595,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'CEvT7nuxANng_sUb3C1J9U5s_ZPOauAQu_grME09whmaXAiL',
#   'summonerName': 'Sardoche Rank1KR',
#   'leaguePoints': 641,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'e9uYfT7VXHUqfyiPTldgOcNkvXuWH03aYiyk9oYo2Z4Q3aQ',
#   'summonerName': 'TLS Misanthiel',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'aT2O38ePi0jbq-4NGQxddD2annTqPdQlCTTpKTDOW7nu926k',
#   'summonerName': 'BSC Coldraa',
#   'leaguePoints': 639,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '7ZydW_-IGWyXjITc-3s-UkVPo60MflXIRvv-mu01k4wjb70',
#   'summonerName': 'v diplex',
#   'leaguePoints': 1505,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 92,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'zlsf_ibWHjSdBuLqT5jmisiRNt9KTlmOGZV7A-QKsVK-Nm4',
#   'summonerName': 'hi im keduii',
#   'leaguePoints': 698,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 93,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'i7KtjfeZf5aKRA0lPsF4DDnGE4hO0bnzmYcfb6uJkBgPwXxN',
#   'summonerName': 'Saajaatoor',
#   'leaguePoints': 642,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5ZFExKQvc45KAez0vQzhTsbnxiuUEC5RSQFeayrme5tsaFo',
#   'summonerName': 'Fanny4ever',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'z358WeELrNn2F5v61IBAZfplZDaSogoyDewXmSAG8ofbLHY',
#   'summonerName': 'caughtt a vibe',
#   'leaguePoints': 567,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'TVoxjit_89SZeQWx0WZ6lZreDJRO-hJfN0u-L8hgJHN2wuEGN9sghfKu0g',
#   'summonerName': 'buff and pretty',
#   'leaguePoints': 794,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 138,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'E_tG5b8fsniiedyTebLLgoFFPMZxVn86HOFq0udx1L5oDqzeLlNFfR5Usw',
#   'summonerName': 'FUARKSTYLE',
#   'leaguePoints': 578,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'wuQN-1pRbE4No6oSuFtMITvptzfD-hA91yhTexdgMRuJNEeC',
#   'summonerName': 'Blazen',
#   'leaguePoints': 581,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'm_WCbkh5hqaaOYUecw6MCcG0YCEbI8QGSKdyxDosa3tlJEsh',
#   'summonerName': 'bob kong',
#   'leaguePoints': 768,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '6SBmqyvHcuew18wCQaaP9MPbBhghr22r46iH6Jgf7hl8pHjh',
#   'summonerName': 'Mersa',
#   'leaguePoints': 580,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8NZ6s70CzCcN1rPiUr4ZZwkvdH9WPhaoEJSYp-MoLbAG31Ja',
#   'summonerName': 'Have changed',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'rWWKw0LTDwpqkVOuFIxYOnTBd5j9f41H_HxWCgyMNPnWkBNK',
#   'summonerName': 'Reeibu',
#   'leaguePoints': 609,
#   'rank': 'I',
#   'wins': 140,
#   'losses': 107,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'QievPFtOckrr0MWqdw0huOn9M64KesgRLerRyp1tSHpSw14',
#   'summonerName': 'USE Dreamer Ace',
#   'leaguePoints': 532,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '7DvZQSrzbXzv5q7JdGpL7GHsI2PGJGTtUH4RqsKf4oDO6FAv',
#   'summonerName': 'Regn',
#   'leaguePoints': 553,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'XoCV1rp8oq7wEgiZyO730D8AoWGNRihShVEJde_FevsMTaE',
#   'summonerName': 'Windslushy',
#   'leaguePoints': 592,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '2KfDLrkDhhrRSv4KMi6md0KTa5Rmw0kb3_qQpgf7UbxXeDk',
#   'summonerName': 'CEO of Volibear',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 't8d6lHzgGRIZcdRcsXFDyrWxUfSg6tn1uE9XcM9oVH_tJk4',
#   'summonerName': 'coing1597',
#   'leaguePoints': 607,
#   'rank': 'I',
#   'wins': 131,
#   'losses': 112,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'PgknOsK6B84qvfUkj6cLG3QYGKLvOcT5knLJsCPRsktCoFQ',
#   'summonerName': 'WιndNα',
#   'leaguePoints': 554,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5EVt_qz3J6VwJMg3bbRSxRDhUy2mZIH3P3ZwvHpe80t8CH8',
#   'summonerName': 'snlgit',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 135,
#   'losses': 117,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'GHiCkZZTDAXWF51j7qIFQPIH1CdOyAo4VpWQ0gUILNEY4Zc',
#   'summonerName': 'REAL BC ',
#   'leaguePoints': 735,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kCS0ghrrm_MINTrqvEB8PFi1Al8ZyVN6jRI_Gyie_KnVgGZm9_nS46hWkQ',
#   'summonerName': 'GRP Kozi',
#   'leaguePoints': 533,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ogos5tQCcijHnPixC6v33m_aZmbRlpfkh9-UArqNJDOfMaah',
#   'summonerName': 'Darkycão',
#   'leaguePoints': 658,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4EWGax4RM2sFP6yf9wm0PVLym8c4iG60SzP2d6zED1Cmj5tlgT1fOmY9yA',
#   'summonerName': 'majom',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'DzK05NMOimMnrF-xc0tYuDIFxH5XxGe-p0-7dSixvuD51H1b',
#   'summonerName': 'twtchtvELOSANTA',
#   'leaguePoints': 619,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 110,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2FCFIw_5CsWO4iMHr0p27tyKidKBwIHs910BtbcZheET-go',
#   'summonerName': '1SNAKE4APES',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ydq6yEOi6irnxkaTbxbPVLNuiNgACMH85d9ajpi5s_MbN4I',
#   'summonerName': 'Roıson',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1wBQ9CMjq3pjgGfJJloEjK-1lzZ3Iig_Hpin6kY-u8silS8',
#   'summonerName': 'ACD',
#   'leaguePoints': 692,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'vtBTcreNF02eGgicNbK-SZNDEU1ecgdGcN3mF9qu5Dd41_E',
#   'summonerName': 'ST4RSCR33N',
#   'leaguePoints': 921,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'Qkjk9bW5l8JvAyhfIdH6LmERKDwPeYVtT2KkmBz08EXoa_o',
#   'summonerName': 'hi im alfarouk',
#   'leaguePoints': 594,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'TlrTHMD_2lAg_WxPdAAczqKeL_DKiJs4MpCaCCAjQXigs6g',
#   'summonerName': 'Shooters Tartu',
#   'leaguePoints': 613,
#   'rank': 'I',
#   'wins': 153,
#   'losses': 131,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'o3WBVs2maOgYdO1DNV59xhbRuvrYY7aY052TLzUFqlfGaQU',
#   'summonerName': 'Stelio Kontοs',
#   'leaguePoints': 553,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'z7Vyir9BxX4Gk1WVYUkUQiTFq3AKBdzyxLDqcJGcVQlJH1U',
#   'summonerName': 'Shubber',
#   'leaguePoints': 538,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '6U9YDLyTxIUROGWKp-MzGpA9Yyz6EVmSFZxZtarGc5x5Dek',
#   'summonerName': 'SeaI',
#   'leaguePoints': 550,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iJNu1VqxPlBKqo0Uz1rshoucd95rni1Pq0oyZ_07plsxma2CzCzr2s-g-A',
#   'summonerName': 'username004',
#   'leaguePoints': 543,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kNPTSdtUvLRgIcj2ptgXLEILhSNfDI1DQHvww22WtwxO6Mk',
#   'summonerName': 'WhiteKnight108',
#   'leaguePoints': 667,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'KFyU_zvPlOW_xm7SDIRjhwlIqUEHwEYxSbOIIMxg0F9lUtDtoh7SNvarhQ',
#   'summonerName': 'Nemo sem0',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jiTE9yPP72e4cnqO02N7XV3KT8alNiDeljP6m23Y1CjOffY',
#   'summonerName': 'Nemky',
#   'leaguePoints': 615,
#   'rank': 'I',
#   'wins': 137,
#   'losses': 123,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'HVVv7fNquMwFdd-P5sBf6DkSqWHkeNIKu02pkZYA06Koa8U',
#   'summonerName': 'JuJuTw0',
#   'leaguePoints': 675,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vXGu5_7U7QbJY4yrF8QDzM_EEt9qVj46q2_cNcwGWAbuS-8',
#   'summonerName': 'ΑNIMAL ABUSER',
#   'leaguePoints': 557,
#   'rank': 'I',
#   'wins': 154,
#   'losses': 108,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'C6Cy4mBHXJlpfWEoustDR57xRJUfsCBIca353M2gpE_aRB2lBwleYF3SmA',
#   'summonerName': 'FRYGOOOOOOOOOOOO',
#   'leaguePoints': 681,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GXD3NZsPDQYcaDtAPIL8x7KBldwkGr5NANv59qfVc8H7iyMGfit9rDUnCQ',
#   'summonerName': 'AngwyKìtten',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BFMs7fMRCH5cK1SHOiWYbEKSue0ApDGMB0pKYoFcOGsvY7zh',
#   'summonerName': 'THE WOO TITAN',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6Rymg8hBHtBqChB_XBvP1TJ0r2dnJV4lWglbpyriWrbfMWk7xX2nOVvPrw',
#   'summonerName': 'ŁPL Top',
#   'leaguePoints': 707,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 103,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ySuJBunjO4wBW5Yg4UrFsIlCmaTQoFBtcCdgoxaPvy8P_CM',
#   'summonerName': 'Aesenar',
#   'leaguePoints': 551,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FeQQ_O5Qg1KP3sanxPMhbliGuiJrPQ1HGukGy2o5YAG1fhqMOTFQPJdTkg',
#   'summonerName': 'KnowMe1',
#   'leaguePoints': 541,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kwix-ntgtRtQgtGuUC4NseUga2tNuZZ7L1_gPiQ1Rz7y47o',
#   'summonerName': '424424424',
#   'leaguePoints': 594,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'omRZc4E_QI2lfme4I95u8mRBf8kvvqNA3aJRpg3RszbtIpuE',
#   'summonerName': 'twtv NyroLoL',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 121,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kA7C1RWZcArQLkuYWvK7rXjhWUUCdp4qttZMjXqO70kY7XIK',
#   'summonerName': 'Shawi Katami',
#   'leaguePoints': 727,
#   'rank': 'I',
#   'wins': 164,
#   'losses': 148,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ISkh5RDCal2wNmz5KyNdT4ci3B6x9e3XtDpyrYKYoQ74L8PE',
#   'summonerName': 'Dropώixz',
#   'leaguePoints': 609,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 96,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'YmiLR6bKhoRWgyESaoWk_0_Bh9_-LnszfPlIPwXgy_4dqmLX1s_2uxNQ4g',
#   'summonerName': 'Galați',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'CEg6j3eIALB-opcYoGKWgOlovku9MQkKcmEyWImIJJ5_Gqo4Worh8dauhw',
#   'summonerName': '5R LUKA1',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'qon8apilLQRDzHVuXgAH8hFvWSsBy7LB8TOGXntxKQwFdrw',
#   'summonerName': 'goldento4st',
#   'leaguePoints': 530,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qnFQzVtDiScrrIEs595somKTpF7j3zr3FfXzAp61RBBg6zQ',
#   'summonerName': 'Hans Landα',
#   'leaguePoints': 639,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4kjRWczQBcWzOjzofMxN-EofZTwHsggDW6d8upuky_OIdPON',
#   'summonerName': 'l Need Blood ',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'IdpLfWqpG_u7NiJeBqzEPiq1txxZZKBvyXGu3ChYBW1Jc_M',
#   'summonerName': 'CallMeTristesse',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'UjWW0q1a5fZw4RFSJU-DtYV-E3EXt7TvGkVkzGfUMGTGf_Fwpm6Fi82EZQ',
#   'summonerName': 'Þabu',
#   'leaguePoints': 754,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 111,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'G8kh98rmgCVQ2wDEAtvvMWd0dOBgoJFUC0zlby6F2SkGeXw',
#   'summonerName': 'Luroxx',
#   'leaguePoints': 668,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'NtfdSlo6bbWVl3ATlaOnJrQ2mTc0I5FrMpKebGyoY18cDeB7',
#   'summonerName': 'Banderas',
#   'leaguePoints': 593,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'GPCGirR9necKsNfnJ6JoArtSqMCk_4opwrqRRoCiUFFKh_E',
#   'summonerName': 'TURBO ABUSER XDD',
#   'leaguePoints': 699,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'EqWWtG9jRU81uWIEbEhAWhu_po_0HjKndEAyORA_QYz8C6QdHbUMfWXDEQ',
#   'summonerName': 'QKI1',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HkTFSvlpVcvtA74yhv4mTAx6Arb79RrvqDa-YFmQzsACQFg',
#   'summonerName': 'EMDDD',
#   'leaguePoints': 959,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 110,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'nlFGdjUE2GIu3s8TJKNbVMO8rXMTYFQjQmbC38BSbTdyDUU',
#   'summonerName': 'David Nalbandian',
#   'leaguePoints': 623,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_gnUQzcUL42EIOzD8SUXoQLyLsOSx9UlzeCuEcdymM99Qwg',
#   'summonerName': 'Greed Adventure',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lFbfGMq0AMJiZs9DTEwgDQnLNV83-j_sDOZcrrSkZD_TKic',
#   'summonerName': 'Valenjin',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'tQQZeg1Sws-qRFPs8WgL9LUMsjRuUBs-d0CGnpkzUnZwIXs',
#   'summonerName': 'ABDERZACK01',
#   'leaguePoints': 625,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qZ4_GJsTlQwL424bwL1HzOb1cG1dFGoWSfcIwPDb513aa1sJ',
#   'summonerName': 'Litny',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kbYhuSyc9qSSyx5flePRJEJ961Y1hVAbqFAasjV_8HjxBOs',
#   'summonerName': 'knurteert',
#   'leaguePoints': 570,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ycJiug80Xhz2-FMHcudtmVieMAsTQ6B8NDByX2NmDr02VTg',
#   'summonerName': 'Yi Zuo Da Shan ',
#   'leaguePoints': 527,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Lb3rxKbvJLkWvmw9sns89nZGlujq8e0eAx4Uj8kbfYv0oSE',
#   'summonerName': 'TTV Potent213',
#   'leaguePoints': 996,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WOolexj5uulpEnQTAPJF0wU4i_opPuS44TDLTYg4H24lximC5yUjULKcOg',
#   'summonerName': 'Nubobo',
#   'leaguePoints': 1174,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'MPw6JI27JlSPeCR8Rc_ruDaNrBaymSPfdAB_bJqg7CpSpYU',
#   'summonerName': 'FUN k3y',
#   'leaguePoints': 701,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ov5FF_mDqukXi-fBIC_Og3VlENZQO0AlSeRmkpdnEoBxYKYyOo7fM9Prog',
#   'summonerName': 'death is equal',
#   'leaguePoints': 555,
#   'rank': 'I',
#   'wins': 155,
#   'losses': 136,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'n-SPcJHzsW_WpitzNBMbDCIwei-NPTtWhjBncPGsInb-04vn',
#   'summonerName': 'Presence0',
#   'leaguePoints': 689,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'yk50H_IWqpxZSuy2w_CiEdI8y8rLCF8sHj3F5ZSCYR6gfhae',
#   'summonerName': 'Twtv Strikelol1',
#   'leaguePoints': 709,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 130,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fpyCsRFSRWgHCF_vU3i5r_qBh41JmX5JazmlI2c9qC3J7us',
#   'summonerName': 'Erdotee',
#   'leaguePoints': 701,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FPu5uSVyIQLbKwuEq2DuUesoMser3YcRCAqet_t96lzww5k',
#   'summonerName': 'Gosu Pepper',
#   'leaguePoints': 674,
#   'rank': 'I',
#   'wins': 159,
#   'losses': 138,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8JiIa0tUNzxfED87XVvIoWCkh8CLCNKo8yMvnyUncix5YIsQT6_mEua-bw',
#   'summonerName': 'Villager C',
#   'leaguePoints': 1313,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '2_jAYiyrxwbJQMvgxlgISAo0i8_jFd5AwtvkYu3SW1lOt3wV',
#   'summonerName': 'Lonely Sunrise',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MBVar5ju0oHIPJLc7LRNta57RP0bMtAwMnDWIv0dFDyRTik4',
#   'summonerName': 'RACHMANINOV',
#   'leaguePoints': 593,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FYmZqpFtzhLdCZDbhsDZca-ZigQTJGE-Zo_ZxvpNKVqqp6I',
#   'summonerName': 'FCB XIXAUXAS',
#   'leaguePoints': 606,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 111,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'TbM8KcIT0CA5WeBm5PRx3-hdKS_k-HG-rfVtIcEXvw_fsl8',
#   'summonerName': 'IAimToMisbehave',
#   'leaguePoints': 537,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'LAZZvwJ8qdUv2PexjwE_fbUP_6_yMIlgHv-BXH1HoZkIm60',
#   'summonerName': 'PCS GotzY',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 125,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'i_KIbsXdhGAgomcqZLao1Baf8DvO-bVf8Q4Okt9X2aJ9stk',
#   'summonerName': 'GIA Stend',
#   'leaguePoints': 530,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Z9ShdyXlbxONmO8WllDtq4TfnOHaQ-WOvuXRqk58J55TJ8M',
#   'summonerName': 'GOREDRINKER HAHA',
#   'leaguePoints': 540,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'GI94jkRe1b7cy5VPoIuv9yYAa7k0c96O_ww2LLR0xVdQ6iA',
#   'summonerName': 'BSC Lamabear',
#   'leaguePoints': 717,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'JHpaoGLdxhVnC9UWWScuW6ZDuPUMgjS9QBzqJFj8gSCgqLvhxmogEfgZBw',
#   'summonerName': 'Final Prince',
#   'leaguePoints': 565,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'cFr4B1JVuoygsLw8RbYuXIJtjYSDYvTWxfnHA4dYyuJHEL4',
#   'summonerName': 'BLACKMETALTERROR',
#   'leaguePoints': 811,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'zgFQ_FOoVhU4ITGxlnpSwRPZG4FY_xCxH4CtOmGVS8eG0ClL',
#   'summonerName': 'RhiIech',
#   'leaguePoints': 581,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 116,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'DKFJNRZCPRa1OY7q6tmRzMaXHNNlT7nJOGM10NNh92p9QGk',
#   'summonerName': 'Zergsting',
#   'leaguePoints': 674,
#   'rank': 'I',
#   'wins': 135,
#   'losses': 118,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kikIdVwUawWFMl4J4bYiVQQE8_XctVjwaYl3lJe_yf4YyPcC',
#   'summonerName': 'je peux changer',
#   'leaguePoints': 699,
#   'rank': 'I',
#   'wins': 145,
#   'losses': 128,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ytnSe36vqTRJXZibK3mGdgcjYufnv7PlIH9O2ooiR9Oj5EM',
#   'summonerName': 'Yung Trizzy',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dE3uxA6TTuQtr2QKLJwTRzMhrTBqJYU_lMTYLjRsbWe_IXQ',
#   'summonerName': 'Reflect',
#   'leaguePoints': 664,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'mQlL6FQAgMn65o-Yv-WWT_3c7isIVKqVAcMa_BeoqV4IfhXyhAGrb2LMGg',
#   'summonerName': 'itzaragoto',
#   'leaguePoints': 628,
#   'rank': 'I',
#   'wins': 155,
#   'losses': 140,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'TRe0hq9b7cLzAAfVVdtppY6smSA7zvOuBQ5fZp1mP4qy',
#   'summonerName': 'LIL AΙan',
#   'leaguePoints': 577,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'GqupXGGxSO5QyxQtgr5hj2dSY7bz8J0aP4033nn_1Sxh4nk',
#   'summonerName': 'yüzenköfte',
#   'leaguePoints': 1177,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 110,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'QEC9uk5NmdUiqqeo37ylE4r7gTnoCARjSqcjgNCJpYVjte6kOKniaVBHlw',
#   'summonerName': 'ZeriFeetAreClean',
#   'leaguePoints': 575,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'iKcYnY-C6HrrtgTMsAaahQBfAYgxml6DSxnUO8RwCcHOV8s',
#   'summonerName': '420WeabooSlayer',
#   'leaguePoints': 579,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GMBYKxRLXAdLc65xwEytB7DTiQt8sP1fHps9ezB0xLwgfMg_',
#   'summonerName': 'Gilius2',
#   'leaguePoints': 558,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'RISdAX38WJOwnJkV0dU0CsJugKmwR8gxgoMXb6o-38g-OETU',
#   'summonerName': 'brokenblade19',
#   'leaguePoints': 833,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '50s8xKfxFq8jriGlpZAtMiXkHjVpxzsPl3PYMYobieg_qZzGDbsEKNHdSw',
#   'summonerName': 'TWTV DETDERT',
#   'leaguePoints': 538,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ywTQb4gvfDwkRmPDioBO7gitTk280kMQmw_JasbyjX7-XsM',
#   'summonerName': 'DMN Shaolin',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Afgi0mgIWE9E7pUT-XYRB8EO4FUBOYik39F_565cfSZSAbQ',
#   'summonerName': 'Sebeks',
#   'leaguePoints': 682,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'YD3s8zCr1ufkjVtR9XYzAhJWyyYa9dZsNq-5VGDz7tyED_9bg_F6toAHfA',
# ...
#   'rank': 'I',
#   'wins': 85,
#   'losses': 70,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Aej0cL96TB1biAtxSy5AeO6L_h7_WATGlIcQvBWzQ3NxK-oR',
#   'summonerName': 'SMB Chamana',
#   'leaguePoints': 585,
#   'rank': 'I',
#   'wins': 143,
#   'losses': 134,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'anEpHp0gJLih2rFBQ7xyTnkaxCGUoAsghG3cvJCckO94vFo',
#   'summonerName': 'Keia',
#   'leaguePoints': 540,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MJ_BENQNkN7tkbcEGa0cIAqGEIgp0ETFrbb1NanhrKPfF-SP2n_z53XRMw',
#   'summonerName': 'zmywara kaseko',
#   'leaguePoints': 967,
#   'rank': 'I',
#   'wins': 140,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'A48u-xFJMIYp7c1OPQK_NRiUImV3tE9C-pluX5AlggncoLRu',
#   'summonerName': 'Yikeru',
#   'leaguePoints': 765,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ugcOJeqvkm9EXHGD73l1gCesFbkhNrpzgF9ZmlRSwMBsc3UM',
#   'summonerName': 'NEGATIVE MACRO',
#   'leaguePoints': 830,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '7wt8bgMsJNwp751xkzshKt_9Bmkg9n3rtLOfw1FvKJYTTM2YonfUQTxFfA',
#   'summonerName': 'K1BDF7CBNA',
#   'leaguePoints': 667,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'a808e4pHpw_5BxDGL5tDfF9q6rEQ0koLmJrq9CGsprqn-YPR',
#   'summonerName': 'Arveryen',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6dAgbTBTaQkSlUkmY-uJVoWHmTbXq-no40DSxILfkh1b4r8',
#   'summonerName': '92kg 15iq 20cm',
#   'leaguePoints': 825,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 95,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'YXJdDn5KUZBP8u7zLkRG4TLaAF19hUt-Exk6VuwrjQWPGRU',
#   'summonerName': 'Ptatis',
#   'leaguePoints': 529,
#   'rank': 'I',
#   'wins': 92,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'RQx5Etbj9Zp0TrX8CzgtzKs_pGizot6Y6ZUgxnPa2MSekzJb',
#   'summonerName': 'Ag0ny',
#   'leaguePoints': 717,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 111,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'JF6DE0mcw7sJe24SH0RKinpoBWqTNYjmXcvTIDC5fi60mb0H7fmOoQlF8g',
#   'summonerName': 'coldxn',
#   'leaguePoints': 559,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'pYg8YWiJfTmqY1ZTxMWOstT0Svqzxn_PY1J9UPZPLtaEUDo',
#   'summonerName': 'SLY Wakz',
#   'leaguePoints': 646,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 78,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 's_rhBhd6YUAE6AiDFJGjTI-f-bc5xNThnIbD8xSQ_7YcvaU8AYvyAXEA_Q',
#   'summonerName': 'AUR Elramir',
#   'leaguePoints': 543,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'l_S_mibfhMAlKteljMrg9N451twQ4beCM9L6yup_-pmsDzEEw1jsvhn0KQ',
#   'summonerName': 'SnowySteps',
#   'leaguePoints': 883,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'yxZwZS8ksR9JFh2CrQGqMUVG0ak0NKxABc610A1bmio3S1I',
#   'summonerName': 'Targamas',
#   'leaguePoints': 721,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'd9-ut9UwtLxza14VtmyvszuOcRA2LjSQzRylV2-tJJynNrUZ',
#   'summonerName': 'PurePerfect',
#   'leaguePoints': 569,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'RL0rBa2rYdjMtdYWSUZ8MfnHZq8Z0yO17s5ZJeO8ZpAXpG8',
#   'summonerName': 'lennylennylenny',
#   'leaguePoints': 542,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'W2lBTPiz9KvF91O0hD7JVwcOZR06_h5Qub9v2M-S5RSH_8gB',
#   'summonerName': 'Avra 456',
#   'leaguePoints': 705,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9k8zSK_jI8SKIsMloNzN23D6co_kArwT-tBwmYg30Kg1IvKL',
#   'summonerName': 'Tempo Suta',
#   'leaguePoints': 598,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BeT0CzbhsU8rLTW6nTlQqx1M0yPYoG5ZcIp-v4DkuSKvh1Pek3rcXqd_dQ',
#   'summonerName': 'GPUQSXMH',
#   'leaguePoints': 551,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '4gpNBLpnJNNSLMhECaUKp8cQvD5ceCyDr3aF8afP46l2C8U',
#   'summonerName': 'Kítagawa Marin',
#   'leaguePoints': 659,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 109,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Cd33Z7ODG-ffv0NXh4851W9JGOtG0OpihmQ3lpf61hZa2eaY',
#   'summonerName': '17 yo koreankid',
#   'leaguePoints': 625,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'k-N4qM6OKftE7s15prNz4pgSDN8VHMc7uI5DxXtI8esV85o',
#   'summonerName': 'Lathyrus',
#   'leaguePoints': 1057,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 112,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'Gl8shN8kHpuFkp4udD5eofJtsCQHXLJY9EtzBmHfXAUzte0LN_z2BC9zAQ',
#   'summonerName': 'DP Typhoon',
#   'leaguePoints': 538,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'fHXmMtQncNU7Se7duh-y2PrWEzwgJ4Nrivg-oJltjZWvTdY',
#   'summonerName': 'ARC Devn',
#   'leaguePoints': 529,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'fpXOV2uin649VECES6m1-vPMiH99qpbhtLwAbrNbn7a2Z9Q',
#   'summonerName': 'GENK Monk',
#   'leaguePoints': 542,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ESq_VYNSZujlvDQhVQvH2dWNjDNbLKxwjaO65XgF7skNUXs',
#   'summonerName': 'carry Mind',
#   'leaguePoints': 582,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'JKwe6Yc2Iai3ixA1miIAPK_-vQo6WzA_nF5FXw50WIrEWuDu',
#   'summonerName': 'FULLCLEARING XD',
#   'leaguePoints': 889,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'WW_CiLwo2qZ-2aLyFWydEeK3HkK7qdmMyCeDwk-eiCmSfvmN',
#   'summonerName': 'Pusi Puu',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'TQGEjo53X-tjI12hb--LvBs3DhhWDVWE1cSW-KnKWfmZJ_c',
#   'summonerName': 'Bernitolegend3',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 123,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Wgs0dYsgYwBr3NbQSkF3XrtCTf_CUmJR6jo8z6r0aVHa1tzRk8zgna9Ycw',
#   'summonerName': 'HMPeiWan Cute',
#   'leaguePoints': 530,
#   'rank': 'I',
#   'wins': 135,
#   'losses': 124,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Ai_O6QPTczAf9Nz4kujufSHJbvteOHIIUvJDcnHmmCBLQjU',
#   'summonerName': 'Unknown AD',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'QZ2ubcJbD_aNuIafbpJIZRgPApTh-P577xNbsqsFy-ci0toIhKLCwaWuiQ',
#   'summonerName': 'FGTSZN',
#   'leaguePoints': 573,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'cdeJ4lJGX0n-L8ym1r3O7VTkCVlNF0C7hb5P-tsMKj_XBDWQ',
#   'summonerName': 'Qnoxs',
#   'leaguePoints': 1000,
#   'rank': 'I',
#   'wins': 179,
#   'losses': 156,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'YP9bmTidmPjAd4KK3zogBCdu2ageKJtPM2-DjiA97TMRBds',
#   'summonerName': 'Maxlore',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lfoisiaDVCYGTogf5eKUdhFSzxf7T0XlKrx3cGg9CoHy-J0',
#   'summonerName': 'Νisqy',
#   'leaguePoints': 1180,
#   'rank': 'I',
#   'wins': 155,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'EqipEPs8gG7hsYgJHbrcPwQUMsH1ZUcZVGovlDhhv7OOGjo',
#   'summonerName': 'GENK Guertas',
#   'leaguePoints': 669,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ET0QJEzRm2fVqBHDU83qKSTIMigwn2QzLw1h6UJaU_1ZvWU',
#   'summonerName': 'Tore den store',
#   'leaguePoints': 595,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'P7E-eHdQr1JkO2CFpBgwuAh5echF1hrvBuk7cw3YLROj_xk',
#   'summonerName': 'HMPeiWan Áir',
#   'leaguePoints': 573,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BTpvw9HjRV6opBxo_XpytScGSqwWBPOFmFWa_7wgTDJn2G0',
#   'summonerName': 'MAD Unforgiven0',
#   'leaguePoints': 802,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'xLdQjFQjOHWgSIWVs4r7ZmrVj1ha_-2I7dO3iywj5zNEwQC6',
#   'summonerName': 'Jopa1',
#   'leaguePoints': 702,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'OP9mturp7KBPIYcN-XQLbQZozG-yT4iapowVjdXXyQt1Myo',
#   'summonerName': 'twitchtvSend0o',
#   'leaguePoints': 1137,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Rp_d0RPZB5NIi6N0pteeWv01sOP978V0NvY-vJ06NrDDJTo',
#   'summonerName': 'Steryd',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Vke3RrYJG6yTnwDzDfVNjxIGYiNkr3rWVD4TxWgZ9vc-XR_2dXU4RyKrPw',
#   'summonerName': 'Meshade1',
#   'leaguePoints': 723,
#   'rank': 'I',
#   'wins': 154,
#   'losses': 133,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oyfGC2DakcGX60NHd0HW88_gq8pD_QUhro1jS2-FYNioKBBR',
#   'summonerName': 'BUFF KEQING',
#   'leaguePoints': 744,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'cNB1dJRTuNICBXJ0q8u6tODfO2ugFSc_lVry4jUp_xBpXlAQ',
#   'summonerName': 'Artix P',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'F-rC5K0edFYCxZoZW_fNe147qJK03leGYfJqXkwoV5oel-k',
#   'summonerName': 'ayekasia',
#   'leaguePoints': 553,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Sj0qEjJBaieRA0c3ZZUS95uNSeMxui4hmIb0rkMKKc4_J8o',
#   'summonerName': '2899',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 125,
#   'losses': 115,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'C8yOGbyJWFr1L8PZhuRhzm69dLDo4L7TRf1L4UQw6WXJEbU2rWtBb3DQJg',
#   'summonerName': 'mrzκ',
#   'leaguePoints': 821,
#   'rank': 'I',
#   'wins': 178,
#   'losses': 155,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'frNusSMFuMao78P4PmwzRYRINYXy8uHQWmS_3VG272XEeBs',
#   'summonerName': 'BurnsTaichou',
#   'leaguePoints': 713,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 107,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kmw3ysuMLBZgA45M5zfeM__9jr_ejFj0KlXIsuS_q_qICeQ',
#   'summonerName': 'Maynter',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_-L3i_okB7lXEaV4WAWpxPHYnqqjIt6bg3tjYPAcnMRMFv4',
#   'summonerName': 'LorLor',
#   'leaguePoints': 1022,
#   'rank': 'I',
#   'wins': 163,
#   'losses': 134,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'no932zcyzKaN6T6scWKVkIQSTm1XiRoJUIFMKkf8sDT4ZqA',
#   'summonerName': 'Βruce Wayne',
#   'leaguePoints': 749,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'LOJazXzexYszmXbl8SYMEpmA-WcJUHG5MqnTTn9gq-y29KE',
#   'summonerName': 'LiL TommyG',
#   'leaguePoints': 667,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'rfTf9xThdJ1SMXQwy1BD257qIUU2dTvBU1IbklG4DrVxv3c',
#   'summonerName': 'G2 Plumy',
#   'leaguePoints': 759,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FWYLb9eSQXEgbHeTEJC5Z-tIawpSMHDNS0lJlwTG9pEUGoE',
#   'summonerName': 'Kumugadonkis',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'E2XlGI9f03Oul5CSZmLB4ml5SflP5VAeIKkKq_rbtvsC3gI',
#   'summonerName': 'TheDisconnect',
#   'leaguePoints': 848,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'foy3m9Fx7hFWqrmx22i1ZkW-jAHrSo9Ys0x1ivcmjcLQ3jg',
#   'summonerName': 'Vizícsacsi',
#   'leaguePoints': 707,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'TZqrmWUKxr2UFwTjYnNgso9I2ZBOKlmkFbpOGD8UdZudMiQO',
#   'summonerName': 'patrikk',
#   'leaguePoints': 935,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'yWwV2vL8_Hey_Ww7_rcwKiFDz_eF8gEPGEnNvhfMZEGN7joN',
#   'summonerName': 'Drututt',
#   'leaguePoints': 810,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'vyDt8A7m1_HqJGt_hRDPhNo_ZfHdnDaBfG61q6shx1Gq2cw',
#   'summonerName': 'LGBT heated chop',
#   'leaguePoints': 872,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'sLVS5RVBl48h5IPB3O412LjzT4hJW6W77UO4tJifNxQVctQ',
#   'summonerName': 'LDLC Exakick1',
#   'leaguePoints': 807,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False}]

# %%
grandmaster = riot_api(region + grandmaster_endpoint, creds['key_one'])
master = riot_api(region + master_endpoint, creds['key_one'])

# %%
master_len, grandmaster_len, challenger_len = len(master['entries']), len(grandmaster['entries']), len(challenger['entries'])

print(f'number of master players: {master_len}, grandmaster: {grandmaster_len}, and challenger: {challenger_len}')
# Out:
# number of master players: 3720, grandmaster: 700, and challenger: 300

# %% [markdown]
# # At this point we have some questions to answer.
#
# Our API-keys let us call a maximum of 400 requests every 2 minutes. This means that at a maximum we will only be able ingest 12,000 games per hour, and only time to run the script for ~10 hours. With some loss due to the APIs not perfectly matching the rate limits, we will have 100,000 games of data. We therefore have to carefully construct which games we select.
#
# Many of the top players are known to play against each other all the time, so to save on API calls we need to implement a system to check if the game has already been downloaded.
#
# On top of this, we need to decide whether choosing a broader set of players (~4000) and a small number of games per player (~25 in the worst case scenario) is better or worse than focusing on a smaller set of players, with a larger number of games per player. Since we intend to use pro-players games histories as the supervised set, these will be loaded separately and are not a concern here.
#
# The question is, how many games are needed to determine whether or not someone is a rising star? Given that top tier players play on average 10games/day, what is the absolute minimum length of time needed to get a reasonable sample size?
#
# Borrowing from significance tests, a 'small sample size' below which standard tests such as T-tests are no longer useful to distinguish between normal distributions, is around 20 (below which we need F-tests), so as a ballpark figure this seems a good place to start as the absolute lowest number of games per player.
#
# A different way of looking at the problem will be, without any modelling yet done, can we approximate what kind of data we will need when performing the modelling steps?
#
# ## The (very rough) rough modelling idea will be as follows:
#
# - Semi - supervised: Take games data of each player and cluster players into groups. Each group will have a set number of professionals already in it, and as such groups with high numbers of professionals should in theory contain amateurs that behave as professionals.
# - Supervised: Take a set players performances in a number of matches and identify the professionals. Use this to build a supervised binary classifier to identify whether a players set of performances behave as the pros. We in theory will then be able to interpret instances where strongly incorrectly classified players as those who, though are amateur, *should* be professional. Using Shapley values we will be able to determine feature importance for the classifier and as such identify features which are useful in understanding player performance.
#
#
#
# ## How many features do we have in the match data?
#
# To understand what these algorithms will need to perform well, let's look at the number of base features we get from each match. (Connecting to APIs below)

# %%
region = "europe.api.riotgames.com"
match = "/lol/match/v5/matches/by-puuid/ykmcXq_mFOKMZWMFtR1pdKiz3iL_SSjbxmWw3eaDn4F4GlE-KII7LRQtsA/ids"

test = riot_api(region + match, creds['key_one'])

# %%
# it seems puuid and summonerid are not the same...

test
# Out:
# {'status': {'message': 'Bad Request - Expected message of type puuid, but found summonerId',
#   'status_code': 400}}

# %%
region = "euw1.api.riotgames.com"
random_player = "/lol/summoner/v4/summoners/ykmcXq_mFOKMZWMFtR1pdKiz3iL_SSjbxmWw3eaDn4F4GlE-KII7LRQtsA/"

# %%
test = riot_api(region + random_player, creds['key_one'])

# %%
test
# Out:
# {'id': 'ykmcXq_mFOKMZWMFtR1pdKiz3iL_SSjbxmWw3eaDn4F4GlE-KII7LRQtsA',
#  'accountId': 'cugHSw2kD9xrvRjFkG7VyNesaJAsf4QY6mYaUQmXYbG1b2pcQckGznoj',
#  'puuid': '_un5TMN7ELF20phpmUEg-hHGQkt1siDTDWnQg1duwsvPPWZSCeJWgIRr0rMUHzKbMil5AXIUDXANNQ',
#  'name': 'YOUNG TALENT',
#  'profileIconId': 5128,
#  'revisionDate': 1643222366000,
#  'summonerLevel': 201}

# %%
europe = "europe.api.riotgames.com"
matches_list_endpoint = '/lol/match/v5/matches/by-puuid/' + test['puuid'] +  '/ids'

# default is 20 returned matches, need to add in extra optional arguments to specify range
matches_list =  riot_api(europe + matches_list_endpoint, creds['key_one'])

# %%
matches_list
# Out:
# ['EUW1_5698494054',
#  'EUW1_5697281617',
#  'EUW1_5697193265',
#  'EUW1_5697073881',
#  'EUW1_5696995150',
#  'EUW1_5696878023',
#  'EUW1_5696882146',
#  'EUW1_5696803607',
#  'EUW1_5696648703',
#  'EUW1_5696537695',
#  'EUW1_5696090147',
#  'EUW1_5696126139',
#  'EUW1_5696081836',
#  'EUW1_5695983008',
#  'EUW1_5695924148',
#  'EUW1_5692967563',
#  'EUW1_5692921090',
#  'EUW1_5692705244',
#  'EUW1_5692617738',
#  'EUW1_5692603206']

# %%
one_match_endpoint = '/lol/match/v5/matches/EUW1_5697193265'

one_match_data = riot_api(europe + one_match_endpoint, creds['key_one'])

# %%
# number of features for 1 player in a given game (not all useful however)

print(len(one_match_data['info']['participants'][0]))

one_match_data['info']['participants'][0]
# Out:
# 105
# {'assists': 7,
#  'baronKills': 0,
#  'bountyLevel': 0,
#  'champExperience': 8205,
#  'champLevel': 11,
#  'championId': 266,
#  'championName': 'Aatrox',
#  'championTransform': 0,
#  'consumablesPurchased': 6,
#  'damageDealtToBuildings': 728,
#  'damageDealtToObjectives': 1203,
#  'damageDealtToTurrets': 728,
#  'damageSelfMitigated': 12229,
#  'deaths': 6,
#  'detectorWardsPlaced': 3,
#  'doubleKills': 1,
#  'dragonKills': 0,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': True,
#  'goldEarned': 7690,
#  'goldSpent': 7225,
#  'individualPosition': 'MIDDLE',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 1,
#  'item0': 6630,
#  'item1': 0,
#  'item2': 3133,
#  'item3': 1054,
#  'item4': 3076,
#  'item5': 3047,
#  'item6': 3364,
#  'itemsPurchased': 24,
#  'killingSprees': 1,
#  'kills': 3,
#  'lane': 'MIDDLE',
#  'largestCriticalStrike': 2,
#  'largestKillingSpree': 2,
#  'largestMultiKill': 2,
#  'longestTimeSpentLiving': 347,
#  'magicDamageDealt': 173,
#  'magicDamageDealtToChampions': 17,
#  'magicDamageTaken': 2642,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8010, 'var1': 130, 'var2': 0, 'var3': 0},
#      {'perk': 9111, 'var1': 381, 'var2': 200, 'var3': 0},
#      {'perk': 9104, 'var1': 13, 'var2': 50, 'var3': 0},
#      {'perk': 8299, 'var1': 182, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8242, 'var1': 63, 'var2': 0, 'var3': 0},
#      {'perk': 8473, 'var1': 748, 'var2': 0, 'var3': 0}],
#     'style': 8400}]},
#  'physicalDamageDealt': 53748,
#  'physicalDamageDealtToChampions': 9122,
#  'physicalDamageTaken': 11296,
#  'profileIcon': 5094,
#  'puuid': 'd_F-mdI9s-rYRn5K4rnjJyi9QYVzzpqbrN8rBuHnC0vCLo3LtYSGCulY-WGe-R3obFAGvcK-Gs5Ajw',
#  'quadraKills': 0,
#  'riotIdName': '',
#  'riotIdTagline': '',
#  'role': 'SOLO',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 110,
#  'spell2Casts': 17,
#  'spell3Casts': 69,
#  'spell4Casts': 6,
#  'summoner1Casts': 5,
#  'summoner1Id': 21,
#  'summoner2Casts': 2,
#  'summoner2Id': 4,
#  'summonerId': 'Ic-6Oz0O2qEEYl3xMj7bGFQ0Ii9bMRwsXksRiwc7ERmaxpU',
#  'summonerLevel': 535,
#  'summonerName': 'EG PEIWAN Sao',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'MIDDLE',
#  'timeCCingOthers': 10,
#  'timePlayed': 1418,
#  'totalDamageDealt': 53921,
#  'totalDamageDealtToChampions': 9140,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 16869,
#  'totalHeal': 3960,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 101,
#  'totalTimeCCDealt': 152,
#  'totalTimeSpentDead': 136,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 0,
#  'trueDamageDealtToChampions': 0,
#  'trueDamageTaken': 2931,
#  'turretKills': 0,
#  'turretTakedowns': 1,
#  'turretsLost': 8,
#  'unrealKills': 0,
#  'visionScore': 19,
#  'visionWardsBoughtInGame': 3,
#  'wardsKilled': 3,
#  'wardsPlaced': 8,
#  'win': False}

# %%
timeline_endpoint = '/lol/match/v5/matches/EUW1_5698494054/timeline'
timeline_data = riot_api(europe + timeline_endpoint, creds['key_one'])

timeline_data['info']['frames']['participantFrames']
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_5698494054',
#   'participants': ['d_F-mdI9s-rYRn5K4rnjJyi9QYVzzpqbrN8rBuHnC0vCLo3LtYSGCulY-WGe-R3obFAGvcK-Gs5Ajw',
#    'Xt_b6XX39kLswXAz050elJmr6jDR-YPe0br9ub4iIF_ISnroqohovSG15A-9bTjgP7jfQFZTuFjhTA',
#    'pxprPAKB1HgTJCIbzHTlMZ-ZWc83kEPNqk_4GxhldCa_CZA9GwWTx8IVVDPkADeEvvWQoO85D9CC7w',
#    'KmQNlVkBJ0jYhrlIFSgrpL1Kxtlx6hsE4Tg2YklDp36OwKVN11dBgjInlmcK1CcVmI7vbWt0RShN7w',
#    'OKOvFwwWpS2PMPgs9tXBmqjHGYIumaDVfitvhCd-f-nlfz--NioOWka6n_wrjK9QYbxt-9NM5JxSDg',
#    'uTKkJBshrNZMnLlNkxlbRw9OQ2gwCixHCb2MtemQKB1i6pA4rR04cljYYMf4D3pjDNdg3IxT-Oc2DQ',
#    '_un5TMN7ELF20phpmUEg-hHGQkt1siDTDWnQg1duwsvPPWZSCeJWgIRr0rMUHzKbMil5AXIUDXANNQ',
#    'y16jk6xF5alhCY9vmqTrRrBhfzDVBsw7pwk_R1PeKfcADPftDKai0lN9Y8WirJk2jimJ0zdUjDah8g',
#    'vgNx7oWONHFxMv_3SkunClA8QlGCOeCOdQO3kRkJeLun08OVmXlv-Tk-8Dl_08twaBsSk46ItU7SEw',
#    'qbpSoURdKm2ivhP4uO0Zf6XKWVpUkQXS2_iGQk9eqtSsrWLwxW2fgBVz6MdNfVtLms1fiAGLTJCwIw']},
#  'info': {'frameInterval': 60000,
#   'frames': [{'events': [{'realTimestamp': 1643429925110,
#       'timestamp': 0,
#       'type': 'PAUSE_END'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 580,
#        'healthMax': 580,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 554, 'y': 581},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 39,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 590,
#        'healthMax': 590,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 330,
#        'powerMax': 330,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 557, 'y': 345},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 35,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 570,
#        'healthMax': 570,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 280,
#        'powerMax': 280,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 335, 'y': 269},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 24,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 530,
#        'healthMax': 530,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 375,
#        'powerMax': 375,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 194, 'y': 457},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 22,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 526,
#        'healthMax': 526,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 459,
#        'powerMax': 459,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 329, 'y': 650},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 550,
#        'healthMax': 550,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 300,
#        'powerMax': 300,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 14180, 'y': 14271},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 36,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 570,
#        'healthMax': 570,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 14176, 'y': 14506},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 560,
#        'healthMax': 560,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 14398, 'y': 14582},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 537,
#        'healthMax': 537,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 2,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 14539, 'y': 14394},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 540,
#        'healthMax': 540,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 315,
#        'powerMax': 315,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 14404, 'y': 14201},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0}},
#     'timestamp': 0},
#    {'events': [{'itemId': 1055,
#       'participantId': 1,
#       'timestamp': 2555,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 2555,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 1,
#       'timestamp': 3324,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3850,
#       'participantId': 5,
#       'timestamp': 3525,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 3992,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 4391,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 5,
#       'timestamp': 4658,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1039,
#       'participantId': 7,
#       'timestamp': 4658,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2031,
#       'participantId': 7,
#       'timestamp': 5228,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1055,
#       'participantId': 6,
#       'timestamp': 6938,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 6938,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 6,
#       'timestamp': 7372,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1036,
#       'participantId': 8,
#       'timestamp': 7741,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 7741,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 7741,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 7741,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1035,
#       'participantId': 2,
#       'timestamp': 11373,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 3340,
#       'beforeId': 0,
#       'goldGain': 0,
#       'participantId': 1,
#       'timestamp': 12078,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 3340,
#       'participantId': 2,
#       'timestamp': 12112,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 2003,
#       'goldGain': 50,
#       'participantId': 1,
#       'timestamp': 12247,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 2031,
#       'participantId': 2,
#       'timestamp': 12383,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 1055,
#       'goldGain': 450,
#       'participantId': 1,
#       'timestamp': 12383,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 1054,
#       'participantId': 1,
#       'timestamp': 12919,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 12919,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 1,
#       'timestamp': 13589,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3070,
#       'participantId': 4,
#       'timestamp': 17779,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 4,
#       'timestamp': 17779,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 4,
#       'timestamp': 17779,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1056,
#       'participantId': 9,
#       'timestamp': 19016,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 9,
#       'timestamp': 19016,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 9,
#       'timestamp': 19016,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2033,
#       'participantId': 3,
#       'timestamp': 19685,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 3,
#       'timestamp': 20020,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 1,
#       'timestamp': 21357,
#       'type': 'SKILL_LEVEL_UP'},
#      {'creatorId': 7,
#       'timestamp': 36426,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'itemId': 3340,
#       'participantId': 7,
#       'timestamp': 37460,
#       'type': 'ITEM_DESTROYED'},
#      {'itemId': 3364,
#       'participantId': 7,
#       'timestamp': 37460,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3850,
#       'participantId': 10,
#       'timestamp': 40441,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 42814,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 42914,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 10,
#       'timestamp': 43114,
#       'type': 'ITEM_PURCHASED'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 70,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 660,
#        'healthMax': 660,
#        'healthRegen': 18,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 5624, 'y': 7856},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 9,
#        'armor': 45,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 63,
#        'attackSpeed': 113,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 590,
#        'healthMax': 590,
#        'healthRegen': 17,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 330,
#        'powerMax': 330,
#        'powerRegen': 15,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 5253, 'y': 9126},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 41,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 74,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 570,
#        'healthMax': 570,
#        'healthRegen': 12,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 280,
#        'powerMax': 280,
#        'powerRegen': 15,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 2888, 'y': 11168},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 24,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 65,
#        'attackSpeed': 110,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 530,
#        'healthMax': 530,
#        'healthRegen': 8,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 38,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 615,
#        'powerMax': 615,
#        'powerRegen': 17,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 10294, 'y': 1108},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 28,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 55,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 536,
#        'healthMax': 536,
#        'healthRegen': 11,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 459,
#        'powerMax': 459,
#        'powerRegen': 24,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 20,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 10342, 'y': 907},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 39,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 86,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 630,
#        'healthMax': 630,
#        'healthRegen': 17,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 300,
#        'powerMax': 300,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 6831, 'y': 9542},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 42,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 69,
#        'attackSpeed': 110,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 570,
#        'healthMax': 570,
#        'healthRegen': 15,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 11895, 'y': 7513},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 39,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 79,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 560,
#        'healthMax': 560,
#        'healthRegen': 17,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 6282, 'y': 10125},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 55,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 660,
#        'healthMax': 660,
#        'healthRegen': 14,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 2,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 13519, 'y': 4493},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 62,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 550,
#        'healthMax': 550,
#        'healthRegen': 10,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 40,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 315,
#        'powerMax': 315,
#        'powerRegen': 26,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 20,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 9964, 'y': 6100},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0}},
#     'timestamp': 60024},
#    {'events': [{'itemId': 3340,
#       'participantId': 10,
#       'timestamp': 68642,
#       'type': 'ITEM_DESTROYED'},
#      {'itemId': 3364,
#       'participantId': 10,
#       'timestamp': 68642,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 1,
#       'timestamp': 85706,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 2,
#       'timestamp': 85706,
#       'type': 'SKILL_LEVEL_UP'},
#      {'creatorId': 3,
#       'timestamp': 87198,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 1,
#       'timestamp': 87367,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 3,
#       'timestamp': 88701,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 1,
#       'timestamp': 92406,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 1,
#       'timestamp': 100426,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 1,
#       'timestamp': 100926,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 1,
#       'timestamp': 101926,
#       'type': 'SKILL_LEVEL_UP'},
#      {'level': 2, 'participantId': 2, 'timestamp': 106457, 'type': 'LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 1,
#       'timestamp': 108124,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 3,
#       'timestamp': 109956,
#       'type': 'SKILL_LEVEL_UP'},
#      {'level': 2, 'participantId': 7, 'timestamp': 110359, 'type': 'LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 2,
#       'timestamp': 111095,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 118923,
#       'type': 'ITEM_DESTROYED'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 75,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 17,
#        'cooldownReduction': 0,
#        'health': 496,
#        'healthMax': 660,
#        'healthRegen': 27,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 56,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 486,
#        'physicalDamageDoneToChampions': 249,
#        'physicalDamageTaken': 189,
#        'totalDamageDone': 486,
#        'totalDamageDoneToChampions': 249,
#        'totalDamageTaken': 189,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 2,
#       'participantId': 1,
#       'position': {'x': 6758, 'y': 8612},
#       'timeEnemySpentControlled': 1036,
#       'totalGold': 556,
#       'xp': 211},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 9,
#        'armor': 47,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 65,
#        'attackSpeed': 114,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 21,
#        'cooldownReduction': 0,
#        'health': 404,
#        'healthMax': 658,
#        'healthRegen': 30,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 274,
#        'powerMax': 358,
#        'powerRegen': 43,
#        'spellVamp': 0},
#       'currentGold': 153,
#       'damageStats': {'magicDamageDone': 894,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 1426,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 702,
#        'totalDamageDone': 2943,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 702,
#        'trueDamageDone': 622,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 5,
#       'level': 2,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 8538, 'y': 2382},
#       'timeEnemySpentControlled': 5598,
#       'totalGold': 653,
#       'xp': 407},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 41,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 74,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 551,
#        'healthMax': 579,
#        'healthRegen': 64,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 362,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 199,
#        'powerMax': 280,
#        'powerRegen': 46,
#        'spellVamp': 0},
#       'currentGold': 63,
#       'damageStats': {'magicDamageDone': 50,
#        'magicDamageDoneToChampions': 50,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 429,
#        'physicalDamageDoneToChampions': 204,
#        'physicalDamageTaken': 95,
#        'totalDamageDone': 544,
#        'totalDamageDoneToChampions': 254,
#        'totalDamageTaken': 95,
#        'trueDamageDone': 65,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 2,
#       'participantId': 3,
#       'position': {'x': 1896, 'y': 12982},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 563,
#       'xp': 120},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 24,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 65,
#        'attackSpeed': 120,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 530,
#        'healthMax': 530,
#        'healthRegen': 8,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 38,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 589,
#        'powerMax': 624,
#        'powerRegen': 17,
#        'spellVamp': 0},
#       'currentGold': 84,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 698,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 698,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 3,
#       'participantId': 4,
#       'position': {'x': 12063, 'y': 2074},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 584,
#       'xp': 113},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 28,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 55,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 536,
#        'healthMax': 536,
#        'healthRegen': 11,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 408,
#        'powerMax': 484,
#        'powerRegen': 24,
#        'spellVamp': 0},
#       'currentGold': 52,
#       'damageStats': {'magicDamageDone': 209,
#        'magicDamageDoneToChampions': 58,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 183,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 398,
#        'totalDamageDoneToChampions': 63,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 5,
#        'trueDamageDoneToChampions': 5,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 20,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 12462, 'y': 1390},
#       'timeEnemySpentControlled': 7608,
#       'totalGold': 552,
#       'xp': 113},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 39,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 94,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 21,
#        'cooldownReduction': 0,
#        'health': 369,
#        'healthMax': 630,
#        'healthRegen': 33,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 283,
#        'powerMax': 300,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 77,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 421,
#        'physicalDamageDoneToChampions': 159,
#        'physicalDamageTaken': 310,
#        'totalDamageDone': 421,
#        'totalDamageDoneToChampions': 159,
#        'totalDamageTaken': 310,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 3,
#       'participantId': 6,
#       'position': {'x': 6748, 'y': 8669},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 577,
#       'xp': 211},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 71,
#        'attackSpeed': 111,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 336,
#        'healthMax': 631,
#        'healthRegen': 15,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 100,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 121,
#       'damageStats': {'magicDamageDone': 311,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 222,
#        'physicalDamageDone': 2051,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 494,
#        'totalDamageDone': 2812,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 717,
#        'trueDamageDone': 450,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 2,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 12310, 'y': 6624},
#       'timeEnemySpentControlled': 1702,
#       'totalGold': 621,
#       'xp': 320},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 39,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 79,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 338,
#        'healthMax': 560,
#        'healthRegen': 117,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 63,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 50,
#        'physicalDamageDone': 633,
#        'physicalDamageDoneToChampions': 35,
#        'physicalDamageTaken': 204,
#        'totalDamageDone': 633,
#        'totalDamageDoneToChampions': 35,
#        'totalDamageTaken': 254,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 2,
#       'participantId': 8,
#       'position': {'x': 2532, 'y': 12876},
#       'timeEnemySpentControlled': 1699,
#       'totalGold': 563,
#       'xp': 181},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 55,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 609,
#        'healthMax': 660,
#        'healthRegen': 14,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1,
#        'powerMax': 2,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 63,
#       'damageStats': {'magicDamageDone': 176,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 58,
#        'physicalDamageDone': 303,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 479,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 63,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 5},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 2,
#       'participantId': 9,
#       'position': {'x': 12574, 'y': 2622},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 563,
#       'xp': 113},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 26,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 62,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 550,
#        'healthMax': 550,
#        'healthRegen': 10,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 40,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 315,
#        'powerMax': 315,
#        'powerRegen': 26,
#        'spellVamp': 0},
# ...
#       'timestamp': 1406907,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 1,
#       'timestamp': 1411043,
#       'type': 'SKILL_LEVEL_UP'},
#      {'killerId': 10,
#       'timestamp': 1411043,
#       'type': 'WARD_KILL',
#       'wardType': 'SIGHT_WARD'},
#      {'creatorId': 10,
#       'timestamp': 1411043,
#       'type': 'WARD_PLACED',
#       'wardType': 'UNDEFINED'},
#      {'gameId': 5698494054,
#       'realTimestamp': 1643431343644,
#       'timestamp': 1418480,
#       'type': 'GAME_END',
#       'winningTeam': 200}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 122,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 192,
#        'attackSpeed': 139,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 1890,
#        'healthMax': 1899,
#        'healthRegen': 35,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 42,
#        'movementSpeed': 390,
#        'omnivamp': 10,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 505,
#       'damageStats': {'magicDamageDone': 173,
#        'magicDamageDoneToChampions': 17,
#        'magicDamageTaken': 2642,
#        'physicalDamageDone': 53748,
#        'physicalDamageDoneToChampions': 9122,
#        'physicalDamageTaken': 11296,
#        'totalDamageDone': 53921,
#        'totalDamageDoneToChampions': 9140,
#        'totalDamageTaken': 16869,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 2931},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 11,
#       'minionsKilled': 101,
#       'participantId': 1,
#       'position': {'x': 2420, 'y': 4461},
#       'timeEnemySpentControlled': 152250,
#       'totalGold': 7690,
#       'xp': 8205},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 170,
#        'armor': 169,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 99,
#        'attackSpeed': 202,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 30,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2080,
#        'healthRegen': 29,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 83,
#        'movementSpeed': 385,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 364,
#        'powerMax': 768,
#        'powerRegen': 30,
#        'spellVamp': 0},
#       'currentGold': 533,
#       'damageStats': {'magicDamageDone': 76281,
#        'magicDamageDoneToChampions': 8101,
#        'magicDamageTaken': 4039,
#        'physicalDamageDone': 35276,
#        'physicalDamageDoneToChampions': 2171,
#        'physicalDamageTaken': 16032,
#        'totalDamageDone': 154155,
#        'totalDamageDoneToChampions': 12258,
#        'totalDamageTaken': 23341,
#        'trueDamageDone': 42596,
#        'trueDamageDoneToChampions': 1985,
#        'trueDamageTaken': 3270},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 138,
#       'level': 13,
#       'minionsKilled': 31,
#       'participantId': 2,
#       'position': {'x': 8273, 'y': 7446},
#       'timeEnemySpentControlled': 436893,
#       'totalGold': 9998,
#       'xp': 10652},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 93,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 183,
#        'attackSpeed': 183,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 1547,
#        'healthMax': 2049,
#        'healthRegen': 393,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 45,
#        'movementSpeed': 416,
#        'omnivamp': 2,
#        'physicalVamp': 0,
#        'power': 835,
#        'powerMax': 937,
#        'powerRegen': 30,
#        'spellVamp': 0},
#       'currentGold': 2096,
#       'damageStats': {'magicDamageDone': 10897,
#        'magicDamageDoneToChampions': 2147,
#        'magicDamageTaken': 4437,
#        'physicalDamageDone': 84104,
#        'physicalDamageDoneToChampions': 7609,
#        'physicalDamageTaken': 10911,
#        'totalDamageDone': 100640,
#        'totalDamageDoneToChampions': 11443,
#        'totalDamageTaken': 17359,
#        'trueDamageDone': 5638,
#        'trueDamageDoneToChampions': 1686,
#        'trueDamageTaken': 2010},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 13,
#       'minionsKilled': 147,
#       'participantId': 3,
#       'position': {'x': 12601, 'y': 7375},
#       'timeEnemySpentControlled': 287932,
#       'totalGold': 9664,
#       'xp': 9983},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 62,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 251,
#        'attackSpeed': 137,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 1643,
#        'healthRegen': 22,
#        'lifesteal': 6,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 43,
#        'movementSpeed': 380,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 2007,
#        'powerMax': 2151,
#        'powerRegen': 31,
#        'spellVamp': 0},
#       'currentGold': 834,
#       'damageStats': {'magicDamageDone': 8697,
#        'magicDamageDoneToChampions': 3022,
#        'magicDamageTaken': 5520,
#        'physicalDamageDone': 83183,
#        'physicalDamageDoneToChampions': 7008,
#        'physicalDamageTaken': 4184,
#        'totalDamageDone': 96758,
#        'totalDamageDoneToChampions': 10529,
#        'totalDamageTaken': 10840,
#        'trueDamageDone': 4877,
#        'trueDamageDoneToChampions': 497,
#        'trueDamageTaken': 1135},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 3,
#       'level': 13,
#       'minionsKilled': 177,
#       'participantId': 4,
#       'position': {'x': 7664, 'y': 7572},
#       'timeEnemySpentControlled': 12286,
#       'totalGold': 8649,
#       'xp': 10324},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 189,
#        'armor': 58,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 84,
#        'attackSpeed': 111,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 1508,
#        'healthRegen': 20,
#        'lifesteal': 0,
#        'magicPen': 34,
#        'magicPenPercent': 0,
#        'magicResist': 34,
#        'movementSpeed': 395,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1087,
#        'powerMax': 1652,
#        'powerRegen': 60,
#        'spellVamp': 0},
#       'currentGold': 3154,
#       'damageStats': {'magicDamageDone': 50563,
#        'magicDamageDoneToChampions': 14655,
#        'magicDamageTaken': 2242,
#        'physicalDamageDone': 3782,
#        'physicalDamageDoneToChampions': 857,
#        'physicalDamageTaken': 4321,
#        'totalDamageDone': 54947,
#        'totalDamageDoneToChampions': 16113,
#        'totalDamageTaken': 7250,
#        'trueDamageDone': 600,
#        'trueDamageDoneToChampions': 600,
#        'trueDamageTaken': 685},
#       'goldPerSecond': 30,
#       'jungleMinionsKilled': 5,
#       'level': 11,
#       'minionsKilled': 40,
#       'participantId': 5,
#       'position': {'x': 5235, 'y': 5981},
#       'timeEnemySpentControlled': 212456,
#       'totalGold': 9329,
#       'xp': 8214},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 77,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 319,
#        'attackSpeed': 204,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 10,
#        'cooldownReduction': 0,
#        'health': 1980,
#        'healthMax': 1980,
#        'healthRegen': 29,
#        'lifesteal': 10,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 45,
#        'movementSpeed': 405,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1518,
#        'powerMax': 1595,
#        'powerRegen': 31,
#        'spellVamp': 0},
#       'currentGold': 41,
#       'damageStats': {'magicDamageDone': 1218,
#        'magicDamageDoneToChampions': 778,
#        'magicDamageTaken': 5803,
#        'physicalDamageDone': 110984,
#        'physicalDamageDoneToChampions': 11549,
#        'physicalDamageTaken': 14351,
#        'totalDamageDone': 118374,
#        'totalDamageDoneToChampions': 17224,
#        'totalDamageTaken': 21426,
#        'trueDamageDone': 6171,
#        'trueDamageDoneToChampions': 4897,
#        'trueDamageTaken': 1271},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 13,
#       'minionsKilled': 167,
#       'participantId': 6,
#       'position': {'x': 12055, 'y': 7799},
#       'timeEnemySpentControlled': 356089,
#       'totalGold': 12890,
#       'xp': 10714},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 107,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 273,
#        'attackSpeed': 140,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 2272,
#        'healthMax': 2272,
#        'healthRegen': 30,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 47,
#        'movementSpeed': 390,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 100,
#        'powerMax': 100,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 988,
#       'damageStats': {'magicDamageDone': 7456,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 5744,
#        'physicalDamageDone': 118549,
#        'physicalDamageDoneToChampions': 9388,
#        'physicalDamageTaken': 11123,
#        'totalDamageDone': 145048,
#        'totalDamageDoneToChampions': 12946,
#        'totalDamageTaken': 18017,
#        'trueDamageDone': 19042,
#        'trueDamageDoneToChampions': 3558,
#        'trueDamageTaken': 1149},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 134,
#       'level': 14,
#       'minionsKilled': 34,
#       'participantId': 7,
#       'position': {'x': 4378, 'y': 6109},
#       'timeEnemySpentControlled': 251548,
#       'totalGold': 10848,
#       'xp': 12180},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 94,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 212,
#        'attackSpeed': 162,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 756,
#        'healthMax': 2401,
#        'healthRegen': 27,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 45,
#        'movementSpeed': 489,
#        'omnivamp': 10,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 703,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 5770,
#        'physicalDamageDone': 81357,
#        'physicalDamageDoneToChampions': 8280,
#        'physicalDamageTaken': 10407,
#        'totalDamageDone': 82211,
#        'totalDamageDoneToChampions': 9134,
#        'totalDamageTaken': 17471,
#        'trueDamageDone': 854,
#        'trueDamageDoneToChampions': 854,
#        'trueDamageTaken': 1292},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 13,
#       'minionsKilled': 171,
#       'participantId': 8,
#       'position': {'x': 11181, 'y': 7532},
#       'timeEnemySpentControlled': 68385,
#       'totalGold': 9543,
#       'xp': 11165},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 414,
#        'armor': 62,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 91,
#        'attackSpeed': 130,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 2706,
#        'healthMax': 2769,
#        'healthRegen': 28,
#        'lifesteal': 0,
#        'magicPen': 29,
#        'magicPenPercent': 0,
#        'magicResist': 36,
#        'movementSpeed': 385,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1,
#        'powerMax': 2,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 857,
#       'damageStats': {'magicDamageDone': 114252,
#        'magicDamageDoneToChampions': 12495,
#        'magicDamageTaken': 7634,
#        'physicalDamageDone': 14472,
#        'physicalDamageDoneToChampions': 196,
#        'physicalDamageTaken': 11018,
#        'totalDamageDone': 128724,
#        'totalDamageDoneToChampions': 12692,
#        'totalDamageTaken': 19187,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 535},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 16,
#       'level': 14,
#       'minionsKilled': 201,
#       'participantId': 9,
#       'position': {'x': 6216, 'y': 9262},
#       'timeEnemySpentControlled': 50473,
#       'totalGold': 10597,
#       'xp': 12831},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 188,
#        'armor': 62,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 89,
#        'attackSpeed': 129,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 312,
#        'healthMax': 1522,
#        'healthRegen': 121,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 49,
#        'movementSpeed': 486,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1075,
#        'powerMax': 1302,
#        'powerRegen': 50,
#        'spellVamp': 0},
#       'currentGold': 497,
#       'damageStats': {'magicDamageDone': 6005,
#        'magicDamageDoneToChampions': 4039,
#        'magicDamageTaken': 5478,
#        'physicalDamageDone': 2639,
#        'physicalDamageDoneToChampions': 655,
#        'physicalDamageTaken': 5307,
#        'totalDamageDone': 9367,
#        'totalDamageDoneToChampions': 5418,
#        'totalDamageTaken': 11307,
#        'trueDamageDone': 723,
#        'trueDamageDoneToChampions': 723,
#        'trueDamageTaken': 521},
#       'goldPerSecond': 30,
#       'jungleMinionsKilled': 0,
#       'level': 10,
#       'minionsKilled': 11,
#       'participantId': 10,
#       'position': {'x': 6778, 'y': 9410},
#       'timeEnemySpentControlled': 49007,
#       'totalGold': 6231,
#       'xp': 6634}},
#     'timestamp': 1418480}],
#   'gameId': 5698494054,
#   'participants': [{'participantId': 1,
#     'puuid': 'd_F-mdI9s-rYRn5K4rnjJyi9QYVzzpqbrN8rBuHnC0vCLo3LtYSGCulY-WGe-R3obFAGvcK-Gs5Ajw'},
#    {'participantId': 2,
#     'puuid': 'Xt_b6XX39kLswXAz050elJmr6jDR-YPe0br9ub4iIF_ISnroqohovSG15A-9bTjgP7jfQFZTuFjhTA'},
#    {'participantId': 3,
#     'puuid': 'pxprPAKB1HgTJCIbzHTlMZ-ZWc83kEPNqk_4GxhldCa_CZA9GwWTx8IVVDPkADeEvvWQoO85D9CC7w'},
#    {'participantId': 4,
#     'puuid': 'KmQNlVkBJ0jYhrlIFSgrpL1Kxtlx6hsE4Tg2YklDp36OwKVN11dBgjInlmcK1CcVmI7vbWt0RShN7w'},
#    {'participantId': 5,
#     'puuid': 'OKOvFwwWpS2PMPgs9tXBmqjHGYIumaDVfitvhCd-f-nlfz--NioOWka6n_wrjK9QYbxt-9NM5JxSDg'},
#    {'participantId': 6,
#     'puuid': 'uTKkJBshrNZMnLlNkxlbRw9OQ2gwCixHCb2MtemQKB1i6pA4rR04cljYYMf4D3pjDNdg3IxT-Oc2DQ'},
#    {'participantId': 7,
#     'puuid': '_un5TMN7ELF20phpmUEg-hHGQkt1siDTDWnQg1duwsvPPWZSCeJWgIRr0rMUHzKbMil5AXIUDXANNQ'},
#    {'participantId': 8,
#     'puuid': 'y16jk6xF5alhCY9vmqTrRrBhfzDVBsw7pwk_R1PeKfcADPftDKai0lN9Y8WirJk2jimJ0zdUjDah8g'},
#    {'participantId': 9,
#     'puuid': 'vgNx7oWONHFxMv_3SkunClA8QlGCOeCOdQO3kRkJeLun08OVmXlv-Tk-8Dl_08twaBsSk46ItU7SEw'},
#    {'participantId': 10,
#     'puuid': 'qbpSoURdKm2ivhP4uO0Zf6XKWVpUkQXS2_iGQk9eqtSsrWLwxW2fgBVz6MdNfVtLms1fiAGLTJCwIw'}]}}

# %% [markdown]
# # It turns out we have two separate sources for one match. Timeline (in-game data) and Summary data.
#
# # Now we have seen one Timeline and one Match call, we are in a better position to answer our data-related questions.
#
# There are more features in every match (in that of summary statistics, ~105 features), and the timeline data (containing a snapshot of each player in every minute of the game, in combination with any 'events' that take place throughout the game. This includes thousands of 'features' (though at this point it would be infeasible to include all in a model).
#
# There used to be a conversation in 'how much data do we need to cover the possible vector space of N features'. Generally speaking people would say '2^N datapoints'. In reality this is not the case, however if there is a take home message from this, it's that, in ML terms, more data on a player will lead to better quality predictions. (Though that is not strictly what we are trying to do here, if models perform better, the feature importance done after will also be better).
#
# Qualitatively speaking, 4,000 players feels too much - we will have a set of ~50-100 professional players (and even fewer stars) and we will want to identify amateurs playing around this level. In the top tiers of play, there are three brackets. The top with 300 players, the second with 700 players, and the third with a few thousand (in this case 3720). A measure of the existing frequency of professional players within each bracket will tell us at a very baseline case what the 'odds' are that a pro is in this group. However it decreases significantly with each bracket (it is already well understood that the rating of a player is strongly correlated with skill level).
#
# Therefore to get a good mix of amateurs playing with pros, we will take a look at the top 1,000 players, giving us 100 games/ player. This should be enough to cancel out any randomness cause by 'lucky games' or 'unlucky games', whilst keeping a balance of a larger number of amateurs than professionals. The extremely high dimensionality of the data is still a problem in this case, but that will have to be dealt with separately. (When has too much data ever been a problem?)
#
# ## Finally: Are we going to use Match Summaries **and** timelines, or just one?
#
# In principle everything in the match summaries data can be calculated from the timeline - however this will be time consuming and there are some handy statistics readily available to us in this data. So we will keep both.
#
# Therefore we should expect that without any overlapping games we will have in the end just 50 games per player. This is still markedly above our 20 minimum criteria, so we won't reduce the total number of players we look at any further.
#
# With all that out the way, let's call start getting our data!

# %% [markdown]
# # The quick and dirty data collection method
#
# ## Step 1: Collect a list of ~50,000 match_id's
#
# ## Step 2: Chunk into groups of 1,000, and call the api for each of these games.
#
# - Append each result to a dataframe and save this dataframe to a file in a data folder. Leave running for ~10 hours (overnight), and move the data into a database once the data has been collected.

# %%
#Step 1: Collect a list of 50,000 match ids:

players = challenger['entries'] + grandmaster['entries']
players
# Out:
# [{'summonerId': 'BUpbqiivzJcwwTE5K61m2EvesrfpjR-uywQ_bp51Q03oaj0',
#   'summonerName': 'motus vetiti',
#   'leaguePoints': 820,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'JmkODrIn4ql6MBWZBB8z2pAT8CXGGzvtFwE32VOq8kQPYxUT',
#   'summonerName': 'JDX7 Odi11',
#   'leaguePoints': 902,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 115,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ykmcXq_mFOKMZWMFtR1pdKiz3iL_SSjbxmWw3eaDn4F4GlE-KII7LRQtsA',
#   'summonerName': 'YOUNG TALENT',
#   'leaguePoints': 636,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BykFSgMA-hkbuPdF3AE63gvGZ6b4L77X_9T4-J8Ed2PNyQM',
#   'summonerName': 'TakeSet sama',
#   'leaguePoints': 575,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'C8j4KeNHsR4PoXSDDfQTsilH-q2LmeltSm3GIoZeKrU-pG8i',
#   'summonerName': 'ssimpli',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'amDqltQIitAoqm5lU8RWzOi53DdRbYLY1WVTrcalp9uchza0',
#   'summonerName': 'the pebble',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'C8geiL2bSEJUvZcNWgj5OMlQFl5OVMnf7d_2SQYqirnZjnc',
#   'summonerName': 'Bielefeld',
#   'leaguePoints': 661,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'cTvBXuTMWna1vtiCjo_cf6_fDAuJ3qSFpbmfWWBzx4bmjVRA',
#   'summonerName': 'call of power',
#   'leaguePoints': 700,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kQvMwc4Un9qN7PoFzq1EU00fGPcjGft1IyhP3oiM5nqrih4',
#   'summonerName': 'BiIly Kimber',
#   'leaguePoints': 549,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Qy8iX9A5FGLj_MFrIIv1UK3r-JuGWjbFNPPtdTCpHPB-8inV4OgtSOfHFA',
#   'summonerName': 'YXZ12345',
#   'leaguePoints': 576,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'yRc6e8FspfxT8cT-pfZxjycrJn2X4aqxI2pfKQ-85ITRaaq2ri68UmldWg',
#   'summonerName': 'EMENES',
#   'leaguePoints': 543,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GOISWmIXrI4zWFuDgKo3vA9o9wj7JaXuc1M5uP1GjRvQZ_0',
#   'summonerName': 'Maςaquiñø',
#   'leaguePoints': 555,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'a4wCLXmINkIhNKSa1tFBn9vzxSlON4v_4Y0Mwfm44xkpfy9qGerlDMUFmg',
#   'summonerName': 'Fleshy1',
#   'leaguePoints': 567,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'NsLwF6zk-fdXVPcceJuVfi7rUCkKgONIslZHtOshmNM_-L_BtsvO-d7bRA',
#   'summonerName': 'Truncapochas',
#   'leaguePoints': 688,
#   'rank': 'I',
#   'wins': 121,
#   'losses': 97,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dtp20vLNkB5_BtuaXd9A2kvsa-Z-515qgcr_4EhEQCq318A',
#   'summonerName': 'Eason Gaming ',
#   'leaguePoints': 1026,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5X62b3Wg1VodDwMN7G6cqHlnokTbweWmifEotmZg12NP0Qhd74GtI657lg',
#   'summonerName': 'GGorabakda',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'JkxZLRAHmoR74g9otkTfqHyMOqmpNpNEQvDsboXbzr-iX3fk',
#   'summonerName': 'Thebausffs',
#   'leaguePoints': 565,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '__uDfBDwgb0LL60IswWaumGXXzo6ZC-k9EDmSUQiTivq5gU',
#   'summonerName': 'THE CHREAK',
#   'leaguePoints': 571,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'uvDTM4HRKCOHpxPOO8As7gFmDREhsbh63a-djRKs9AxTmf4qx-7TQ50y1Q',
#   'summonerName': 'AIba Madalyon',
#   'leaguePoints': 660,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VlGIbjkrS1dfkeV_o_BX00Am5_ZlhLeUrUnjjzTrk02jY0o',
#   'summonerName': 'MSF Irrelevant',
#   'leaguePoints': 822,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '8VZlOT8yf6-k0MqSxKjN0RzFm8giPFRLqIvJxL2c60cv5ns',
#   'summonerName': 'Aítana Øcaña',
#   'leaguePoints': 628,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '80S5Z0G__umAiWFIUsJtphZnTdSs4J9PQl8kgszYxe8M8ow',
#   'summonerName': 'Ekko the Neeko',
#   'leaguePoints': 726,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'oG75iOV-keJ7XwWKxKxFqm4wb3xbgREe468e8CWEKatU-G8',
#   'summonerName': 'school phobia',
#   'leaguePoints': 969,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'pKxA5ASDWaGnSwTwNhMSiKuc3379zRQRBRU7AmPMqco_3J6B',
#   'summonerName': 'Augenringe',
#   'leaguePoints': 600,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qJs8_Ve-1_3vT7MtffbOWpkw-u-JE87myRb_LQpseHdn2-k',
#   'summonerName': 'xFlavour4youGirl',
#   'leaguePoints': 819,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fwAc6k59NhHfrnrVWKmq9Qw8oYH1uJkSi-DnjavbbvP87QuXBDelJAruxA',
#   'summonerName': 'TwTv rawrbenXD',
#   'leaguePoints': 811,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 119,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'UKX0K41jEIJSsP0WkDh1XfqvLMRZn2hJ-ovLSH5l4ieTsjA',
#   'summonerName': 'pve guy',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 129,
#   'losses': 115,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 's2PFXSmLff1I61OBCOwaEQdvpfxetgMm4aRiTkPdyjcQDq0',
#   'summonerName': 'KC Rekkles',
#   'leaguePoints': 837,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'KEXnewQWO7TPVv25S7oKaMzKBEVCPWe7lFQX4cJVTILA1eNl',
#   'summonerName': 'G2 Dream',
#   'leaguePoints': 778,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '8yEVMv9J3REd5c9qKYvNPA4aF4ZPhzcPdJYti50tEsHypuU',
#   'summonerName': 'Agurin',
#   'leaguePoints': 1171,
#   'rank': 'I',
#   'wins': 128,
#   'losses': 106,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9AoLnGzDSpJA7oFSokMf3Ddr1OKuq9upv69L96I1AGLyYg7L',
#   'summonerName': 'gdgd',
#   'leaguePoints': 561,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'RUw5mGVWE4kOu4RDpQVPRBwoqqKc1Viw0FE58Kgl70GlUa8',
#   'summonerName': 'A41G Relative',
#   'leaguePoints': 561,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'NiwN6UnBqi07F9agR6HsErS9Kdz0T8LzVPlxUZEdAOWbAmNb',
#   'summonerName': 'TWTVBioticZilean',
#   'leaguePoints': 811,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 112,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'hcdwMeApAJGewH6BykjrT8utguYpLRafhn_qWnAVRW52DNaK',
#   'summonerName': 'Foutriquet',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'XcyF_qMFgcY3J_a3xeML6UGQiYjZc9isFMoNSdfRzUWgsShV151BWyjORw',
#   'summonerName': 'dzc',
#   'leaguePoints': 737,
#   'rank': 'I',
#   'wins': 167,
#   'losses': 146,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'TxpTdpOlspxjwxcvhLwysSzs0xwc5bhVS3fgU6muKFe2vcvE',
#   'summonerName': 'TTV RinANB',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Ic-6Oz0O2qEEYl3xMj7bGFQ0Ii9bMRwsXksRiwc7ERmaxpU',
#   'summonerName': 'EG PEIWAN Sao',
#   'leaguePoints': 819,
#   'rank': 'I',
#   'wins': 143,
#   'losses': 123,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'LacL-faZUdaYidDUGj8RjNh1Ipe_gXyPtmA0bkCk-03SZKux',
#   'summonerName': 'Baby Tarz1',
#   'leaguePoints': 550,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'K7MvTur0hUSjApxHClAjmOK9mqjOFOj-ZyFP_J3XDdrSHj0',
#   'summonerName': 'Monsieur Oui',
#   'leaguePoints': 550,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uTLTFVHEGgGRMqNZXmIEtbvJlV96ui-ov-v-odWXIAF8OUfh',
#   'summonerName': 'ÀitchAre',
#   'leaguePoints': 706,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'F8RdLr01x1JKIgLW6HqIueiL2q6EvOpzoXVIW2YybTf0w7g',
#   'summonerName': 'GODZILLA66666666',
#   'leaguePoints': 714,
#   'rank': 'I',
#   'wins': 151,
#   'losses': 141,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'KcQoNqsjaduqCtj1sPjGIrysmo_y9D35YK6hg_uqB9SZUEQ',
#   'summonerName': 'Nartock',
#   'leaguePoints': 599,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dKTd8oyGFtRiUybgNyaBCijKLNb1yYZm7JAz-xkeubPOU8s',
#   'summonerName': 'SlNGED',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'p4FKNr4ZqCtiOIqbEn5kPWeIi00JixLjFJA-Mb9kz1MFdqY',
#   'summonerName': 'Don Noway',
#   'leaguePoints': 1067,
#   'rank': 'I',
#   'wins': 138,
#   'losses': 115,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'VYD7lkK225NNFXnlZSQiowK9TyxDSDnvyvtqFb3mNLuRy83n',
#   'summonerName': 'devil gecko',
#   'leaguePoints': 757,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'CXcWmMQbg0iqzlxo-smfAKFEY_kO2GBqEzZ3yUIyblYe7cN5Jbtp9wXUwQ',
#   'summonerName': 'NOBREAK999999999',
#   'leaguePoints': 769,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'FY3nULJAQ3qH9jnMmLFuHw_EOMNUlIqrR2_8go-FN5H4ttSG',
#   'summonerName': 'golem of glory',
#   'leaguePoints': 557,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ieQ2-LrV4-mqR8LHB6gtiNlDlw2lROaGCBVCzkpUuJm7Je8xuTT5Qt-J2A',
#   'summonerName': 'Sunflοwer',
#   'leaguePoints': 1158,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 96,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fhxJhLpY_ioShZZWpJJTeHLXN4clezBAWV1mCS1QmwiG2FY',
#   'summonerName': 'POOPY PANTIES xD',
#   'leaguePoints': 625,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'J8NcsYG_yfdado7SwfvO2LZOtXQjozLKxG9DtN6FHcX_JmA',
#   'summonerName': 'Thebigestnoob1',
#   'leaguePoints': 676,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'BAo8ZgSkdxhYfbdOf33cu8XFBQGrWC3NOdMzkwp7MsU0FNg',
#   'summonerName': '2022mvp',
#   'leaguePoints': 1239,
#   'rank': 'I',
#   'wins': 129,
#   'losses': 96,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'RorrufXwg8gZaxQ-iMGiBcA8MI7HW-X-ykx-y3YjgL3JJas',
#   'summonerName': 'Iκιωι',
#   'leaguePoints': 603,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_YPssODQvpAWjBu7_Y-8DesU1lKhzOas0qVO4ze0YrMPlDOe',
#   'summonerName': 'AF Nano',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 125,
#   'losses': 110,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-d9BIf8pJ17W0tLMVh7uRNVnvQ7GU5F1gMRCHqcoLB_-8hQ-',
#   'summonerName': 'zta',
#   'leaguePoints': 913,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'QUNeBPbQR-t1hmMoZ0v5NVdo1jYVyTR782JU4qGS1S2rDV5H',
#   'summonerName': 'BJK Jeyrus',
#   'leaguePoints': 692,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'DmQtWMewndUmE0lH6yOrXvk-09fURvEFtaCRJSEb5QDvhxo8',
#   'summonerName': 'SMB Neramin',
#   'leaguePoints': 822,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'tbkJhRnb1l2l9TbvwAAkBcZ8BalnaJvbO5YqpOmiNmxtlVo',
#   'summonerName': 'KC Hantera1',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '43p_QncwD80tnDq5G3Egm6Rh_HYDEFcFipW0G3aYNqvdL72O',
#   'summonerName': 'huntiandi1',
#   'leaguePoints': 760,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '85YrrILIsDPn7p8NSYIM15f5qaIox1Ec9_KvQLs60YWlPvA',
#   'summonerName': 'Skream Takeover',
#   'leaguePoints': 735,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'iMGfBzxkodN9x9yoqgVHV_o2wCDVt6yW2OylDazZ8JHeL_E',
#   'summonerName': 'silkysmath',
#   'leaguePoints': 627,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'qZ8dTNWtDMid5xPZ1zUpxBrN_iBjFkhUUMPnI-ghLab_mIxL',
#   'summonerName': 'BJK Lot',
#   'leaguePoints': 697,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Tg1FSzUFs6n_fdk2PKsGbjPS94f9hwm-192vU-ZmHV9rV-8',
#   'summonerName': 'Katare',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GQb8dh7h7ITZBL5jQYv6CSzmnD0AneUZ3oLQnOWOQ3CFRr0',
#   'summonerName': 'EDEN F0X',
#   'leaguePoints': 554,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ZNz_Gnu0VyBCnfhZF4KBWdab0x_DwLsd7YepU4yKzPVdgks',
#   'summonerName': 'Jae',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 157,
#   'losses': 142,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'L5wsPtzgSUGAGlSMN1suSixl1QuoizsZ8pwPEjPo0V0XBLA',
#   'summonerName': 'CaÞs',
#   'leaguePoints': 1012,
#   'rank': 'I',
#   'wins': 124,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'rXybYkeOklmco3OoigqEKtHgMKIqDhDrk22CJ6EqOM73W48',
#   'summonerName': 'Spirgius',
#   'leaguePoints': 540,
#   'rank': 'I',
#   'wins': 146,
#   'losses': 130,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iRdTiWWLFW_Gi5qGbbzFix8u7vJzkkuv2ZX8Ochuf3S4PNuyDMTD3x2cAg',
#   'summonerName': 'SPOLFCEI',
#   'leaguePoints': 643,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'hhc1eL5HtK8i_FHOJV81kUjpL5n1B1UbVkv_jsf_GUb1uYyzh616yTTz5A',
#   'summonerName': 'Þyke Mid',
#   'leaguePoints': 716,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lJNy7dWHmpsA0G8iV2SRopFjlKl8vwP1Rq60ninTPP6LF1M',
#   'summonerName': 'foukinha gostosa',
#   'leaguePoints': 549,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'g7gGlvfQ-9oW53bdtD4HlsS0I5kqZr-kwY86hApjrf6-I6Q',
#   'summonerName': 'Elite500',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'z2Ye894uNOlekhM09G68q7Uxi4BvBJlBHtP4gHphnpGbPJw7',
#   'summonerName': 'zz why 3lue',
#   'leaguePoints': 812,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YfpLfCLHBWDZU1HeCaewq2YD4BOjmF1ZygQSNvh7hPoZX8Q',
#   'summonerName': 'HIVE Addusto',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'a67TuII-b07H_8jXsy7bqZAk9sIseglwS5gAXnVZL2g23z95TH1tVXAkBA',
#   'summonerName': 'Bagdiamond',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'U-tTZQKr8Jrgg-WUUKGIiFLWk6INBaVDQkIO3QmruMzclwdI',
#   'summonerName': 'Haze 8D',
#   'leaguePoints': 569,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 117,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YlZHQ4xjjpfgyHoXohaQfbdWda_MdLYyO8Ll5q8o2YGfFFo',
#   'summonerName': 'GTZ Pan',
#   'leaguePoints': 737,
#   'rank': 'I',
#   'wins': 120,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'y8ZnHOwvhUY20XvIcstjmvjNhq_GzSW4Zt-VmxEfGdmgMMcx',
#   'summonerName': 'BLU 113',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Sbrwfw2jD6ZSB8y4c-STwdSUNZJXMGhWLZRV2lJJhnF5rfTzadTbQ1NxhA',
#   'summonerName': 'RRubyLOL',
#   'leaguePoints': 828,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 94,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'nWmBpMRHkk_dnUTAwL4Cxs4xfushNraGwJkIFlLO1WXGmU98',
#   'summonerName': 'IW Serin',
#   'leaguePoints': 957,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '-Hqcl-CDz6GgOJN0efkKDAmJsQf9hF86psOkpkwx0GGUSm2Q',
#   'summonerName': 'ATTDÏ',
#   'leaguePoints': 541,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'j13oSank1UwR4lUqMBebVOiB3FF0XgypWB68k5MNvMZAipkK',
#   'summonerName': 'Sorya',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'EtbJotI-yaZ8I-UT2ViWkxleFKjJFWXwIOab2ezD3c-DgUE',
#   'summonerName': 'AHäHäCiK',
#   'leaguePoints': 802,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ZkABBSF4kPNpW2PVeUZ6C6UvMhaI82umMt1l3BEW_NxWZmo',
#   'summonerName': 'VE MetroArcher',
#   'leaguePoints': 595,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'CEvT7nuxANng_sUb3C1J9U5s_ZPOauAQu_grME09whmaXAiL',
#   'summonerName': 'Sardoche Rank1KR',
#   'leaguePoints': 641,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'e9uYfT7VXHUqfyiPTldgOcNkvXuWH03aYiyk9oYo2Z4Q3aQ',
#   'summonerName': 'TLS Misanthiel',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'aT2O38ePi0jbq-4NGQxddD2annTqPdQlCTTpKTDOW7nu926k',
#   'summonerName': 'BSC Coldraa',
#   'leaguePoints': 639,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '7ZydW_-IGWyXjITc-3s-UkVPo60MflXIRvv-mu01k4wjb70',
#   'summonerName': 'v diplex',
#   'leaguePoints': 1505,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 92,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'zlsf_ibWHjSdBuLqT5jmisiRNt9KTlmOGZV7A-QKsVK-Nm4',
#   'summonerName': 'hi im keduii',
#   'leaguePoints': 698,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 93,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'i7KtjfeZf5aKRA0lPsF4DDnGE4hO0bnzmYcfb6uJkBgPwXxN',
#   'summonerName': 'Saajaatoor',
#   'leaguePoints': 642,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5ZFExKQvc45KAez0vQzhTsbnxiuUEC5RSQFeayrme5tsaFo',
#   'summonerName': 'Fanny4ever',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'z358WeELrNn2F5v61IBAZfplZDaSogoyDewXmSAG8ofbLHY',
#   'summonerName': 'caughtt a vibe',
#   'leaguePoints': 567,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'TVoxjit_89SZeQWx0WZ6lZreDJRO-hJfN0u-L8hgJHN2wuEGN9sghfKu0g',
#   'summonerName': 'buff and pretty',
#   'leaguePoints': 794,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 138,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'E_tG5b8fsniiedyTebLLgoFFPMZxVn86HOFq0udx1L5oDqzeLlNFfR5Usw',
#   'summonerName': 'FUARKSTYLE',
#   'leaguePoints': 578,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'wuQN-1pRbE4No6oSuFtMITvptzfD-hA91yhTexdgMRuJNEeC',
#   'summonerName': 'Blazen',
#   'leaguePoints': 581,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'm_WCbkh5hqaaOYUecw6MCcG0YCEbI8QGSKdyxDosa3tlJEsh',
#   'summonerName': 'bob kong',
#   'leaguePoints': 768,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '6SBmqyvHcuew18wCQaaP9MPbBhghr22r46iH6Jgf7hl8pHjh',
#   'summonerName': 'Mersa',
#   'leaguePoints': 580,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8NZ6s70CzCcN1rPiUr4ZZwkvdH9WPhaoEJSYp-MoLbAG31Ja',
#   'summonerName': 'Have changed',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'rWWKw0LTDwpqkVOuFIxYOnTBd5j9f41H_HxWCgyMNPnWkBNK',
#   'summonerName': 'Reeibu',
#   'leaguePoints': 609,
#   'rank': 'I',
#   'wins': 140,
#   'losses': 107,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'QievPFtOckrr0MWqdw0huOn9M64KesgRLerRyp1tSHpSw14',
#   'summonerName': 'USE Dreamer Ace',
#   'leaguePoints': 532,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '7DvZQSrzbXzv5q7JdGpL7GHsI2PGJGTtUH4RqsKf4oDO6FAv',
#   'summonerName': 'Regn',
#   'leaguePoints': 553,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'XoCV1rp8oq7wEgiZyO730D8AoWGNRihShVEJde_FevsMTaE',
#   'summonerName': 'Windslushy',
#   'leaguePoints': 592,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '2KfDLrkDhhrRSv4KMi6md0KTa5Rmw0kb3_qQpgf7UbxXeDk',
#   'summonerName': 'CEO of Volibear',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 't8d6lHzgGRIZcdRcsXFDyrWxUfSg6tn1uE9XcM9oVH_tJk4',
#   'summonerName': 'coing1597',
#   'leaguePoints': 607,
#   'rank': 'I',
#   'wins': 131,
#   'losses': 112,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'PgknOsK6B84qvfUkj6cLG3QYGKLvOcT5knLJsCPRsktCoFQ',
#   'summonerName': 'WιndNα',
#   'leaguePoints': 554,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5EVt_qz3J6VwJMg3bbRSxRDhUy2mZIH3P3ZwvHpe80t8CH8',
#   'summonerName': 'snlgit',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 135,
#   'losses': 117,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'GHiCkZZTDAXWF51j7qIFQPIH1CdOyAo4VpWQ0gUILNEY4Zc',
#   'summonerName': 'REAL BC ',
#   'leaguePoints': 735,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kCS0ghrrm_MINTrqvEB8PFi1Al8ZyVN6jRI_Gyie_KnVgGZm9_nS46hWkQ',
#   'summonerName': 'GRP Kozi',
#   'leaguePoints': 533,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ogos5tQCcijHnPixC6v33m_aZmbRlpfkh9-UArqNJDOfMaah',
#   'summonerName': 'Darkycão',
#   'leaguePoints': 658,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4EWGax4RM2sFP6yf9wm0PVLym8c4iG60SzP2d6zED1Cmj5tlgT1fOmY9yA',
#   'summonerName': 'majom',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'DzK05NMOimMnrF-xc0tYuDIFxH5XxGe-p0-7dSixvuD51H1b',
#   'summonerName': 'twtchtvELOSANTA',
#   'leaguePoints': 619,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 110,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2FCFIw_5CsWO4iMHr0p27tyKidKBwIHs910BtbcZheET-go',
#   'summonerName': '1SNAKE4APES',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ydq6yEOi6irnxkaTbxbPVLNuiNgACMH85d9ajpi5s_MbN4I',
#   'summonerName': 'Roıson',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1wBQ9CMjq3pjgGfJJloEjK-1lzZ3Iig_Hpin6kY-u8silS8',
#   'summonerName': 'ACD',
#   'leaguePoints': 692,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'vtBTcreNF02eGgicNbK-SZNDEU1ecgdGcN3mF9qu5Dd41_E',
#   'summonerName': 'ST4RSCR33N',
#   'leaguePoints': 921,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'Qkjk9bW5l8JvAyhfIdH6LmERKDwPeYVtT2KkmBz08EXoa_o',
#   'summonerName': 'hi im alfarouk',
#   'leaguePoints': 594,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'TlrTHMD_2lAg_WxPdAAczqKeL_DKiJs4MpCaCCAjQXigs6g',
#   'summonerName': 'Shooters Tartu',
#   'leaguePoints': 613,
#   'rank': 'I',
#   'wins': 153,
#   'losses': 131,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'o3WBVs2maOgYdO1DNV59xhbRuvrYY7aY052TLzUFqlfGaQU',
#   'summonerName': 'Stelio Kontοs',
#   'leaguePoints': 553,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'z7Vyir9BxX4Gk1WVYUkUQiTFq3AKBdzyxLDqcJGcVQlJH1U',
#   'summonerName': 'Shubber',
#   'leaguePoints': 538,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '6U9YDLyTxIUROGWKp-MzGpA9Yyz6EVmSFZxZtarGc5x5Dek',
#   'summonerName': 'SeaI',
#   'leaguePoints': 550,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iJNu1VqxPlBKqo0Uz1rshoucd95rni1Pq0oyZ_07plsxma2CzCzr2s-g-A',
#   'summonerName': 'username004',
#   'leaguePoints': 543,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kNPTSdtUvLRgIcj2ptgXLEILhSNfDI1DQHvww22WtwxO6Mk',
#   'summonerName': 'WhiteKnight108',
#   'leaguePoints': 667,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'KFyU_zvPlOW_xm7SDIRjhwlIqUEHwEYxSbOIIMxg0F9lUtDtoh7SNvarhQ',
#   'summonerName': 'Nemo sem0',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jiTE9yPP72e4cnqO02N7XV3KT8alNiDeljP6m23Y1CjOffY',
#   'summonerName': 'Nemky',
#   'leaguePoints': 615,
#   'rank': 'I',
#   'wins': 137,
#   'losses': 123,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'HVVv7fNquMwFdd-P5sBf6DkSqWHkeNIKu02pkZYA06Koa8U',
#   'summonerName': 'JuJuTw0',
#   'leaguePoints': 675,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vXGu5_7U7QbJY4yrF8QDzM_EEt9qVj46q2_cNcwGWAbuS-8',
#   'summonerName': 'ΑNIMAL ABUSER',
#   'leaguePoints': 557,
#   'rank': 'I',
#   'wins': 154,
#   'losses': 108,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'C6Cy4mBHXJlpfWEoustDR57xRJUfsCBIca353M2gpE_aRB2lBwleYF3SmA',
#   'summonerName': 'FRYGOOOOOOOOOOOO',
#   'leaguePoints': 681,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GXD3NZsPDQYcaDtAPIL8x7KBldwkGr5NANv59qfVc8H7iyMGfit9rDUnCQ',
#   'summonerName': 'AngwyKìtten',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BFMs7fMRCH5cK1SHOiWYbEKSue0ApDGMB0pKYoFcOGsvY7zh',
#   'summonerName': 'THE WOO TITAN',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6Rymg8hBHtBqChB_XBvP1TJ0r2dnJV4lWglbpyriWrbfMWk7xX2nOVvPrw',
#   'summonerName': 'ŁPL Top',
#   'leaguePoints': 707,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 103,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ySuJBunjO4wBW5Yg4UrFsIlCmaTQoFBtcCdgoxaPvy8P_CM',
#   'summonerName': 'Aesenar',
#   'leaguePoints': 551,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FeQQ_O5Qg1KP3sanxPMhbliGuiJrPQ1HGukGy2o5YAG1fhqMOTFQPJdTkg',
#   'summonerName': 'KnowMe1',
#   'leaguePoints': 541,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kwix-ntgtRtQgtGuUC4NseUga2tNuZZ7L1_gPiQ1Rz7y47o',
#   'summonerName': '424424424',
#   'leaguePoints': 594,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'omRZc4E_QI2lfme4I95u8mRBf8kvvqNA3aJRpg3RszbtIpuE',
#   'summonerName': 'twtv NyroLoL',
#   'leaguePoints': 544,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 121,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kA7C1RWZcArQLkuYWvK7rXjhWUUCdp4qttZMjXqO70kY7XIK',
#   'summonerName': 'Shawi Katami',
#   'leaguePoints': 727,
#   'rank': 'I',
#   'wins': 164,
#   'losses': 148,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ISkh5RDCal2wNmz5KyNdT4ci3B6x9e3XtDpyrYKYoQ74L8PE',
#   'summonerName': 'Dropώixz',
#   'leaguePoints': 609,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 96,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'YmiLR6bKhoRWgyESaoWk_0_Bh9_-LnszfPlIPwXgy_4dqmLX1s_2uxNQ4g',
#   'summonerName': 'Galați',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'CEg6j3eIALB-opcYoGKWgOlovku9MQkKcmEyWImIJJ5_Gqo4Worh8dauhw',
#   'summonerName': '5R LUKA1',
#   'leaguePoints': 534,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'qon8apilLQRDzHVuXgAH8hFvWSsBy7LB8TOGXntxKQwFdrw',
#   'summonerName': 'goldento4st',
#   'leaguePoints': 530,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qnFQzVtDiScrrIEs595somKTpF7j3zr3FfXzAp61RBBg6zQ',
#   'summonerName': 'Hans Landα',
#   'leaguePoints': 639,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4kjRWczQBcWzOjzofMxN-EofZTwHsggDW6d8upuky_OIdPON',
#   'summonerName': 'l Need Blood ',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'IdpLfWqpG_u7NiJeBqzEPiq1txxZZKBvyXGu3ChYBW1Jc_M',
#   'summonerName': 'CallMeTristesse',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'UjWW0q1a5fZw4RFSJU-DtYV-E3EXt7TvGkVkzGfUMGTGf_Fwpm6Fi82EZQ',
#   'summonerName': 'Þabu',
#   'leaguePoints': 754,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 111,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'G8kh98rmgCVQ2wDEAtvvMWd0dOBgoJFUC0zlby6F2SkGeXw',
#   'summonerName': 'Luroxx',
#   'leaguePoints': 668,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'NtfdSlo6bbWVl3ATlaOnJrQ2mTc0I5FrMpKebGyoY18cDeB7',
#   'summonerName': 'Banderas',
#   'leaguePoints': 593,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'GPCGirR9necKsNfnJ6JoArtSqMCk_4opwrqRRoCiUFFKh_E',
#   'summonerName': 'TURBO ABUSER XDD',
#   'leaguePoints': 699,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'EqWWtG9jRU81uWIEbEhAWhu_po_0HjKndEAyORA_QYz8C6QdHbUMfWXDEQ',
#   'summonerName': 'QKI1',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HkTFSvlpVcvtA74yhv4mTAx6Arb79RrvqDa-YFmQzsACQFg',
#   'summonerName': 'EMDDD',
#   'leaguePoints': 959,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 110,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'nlFGdjUE2GIu3s8TJKNbVMO8rXMTYFQjQmbC38BSbTdyDUU',
#   'summonerName': 'David Nalbandian',
#   'leaguePoints': 623,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_gnUQzcUL42EIOzD8SUXoQLyLsOSx9UlzeCuEcdymM99Qwg',
#   'summonerName': 'Greed Adventure',
#   'leaguePoints': 531,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lFbfGMq0AMJiZs9DTEwgDQnLNV83-j_sDOZcrrSkZD_TKic',
#   'summonerName': 'Valenjin',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'tQQZeg1Sws-qRFPs8WgL9LUMsjRuUBs-d0CGnpkzUnZwIXs',
#   'summonerName': 'ABDERZACK01',
#   'leaguePoints': 625,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qZ4_GJsTlQwL424bwL1HzOb1cG1dFGoWSfcIwPDb513aa1sJ',
#   'summonerName': 'Litny',
#   'leaguePoints': 588,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kbYhuSyc9qSSyx5flePRJEJ961Y1hVAbqFAasjV_8HjxBOs',
#   'summonerName': 'knurteert',
#   'leaguePoints': 570,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ycJiug80Xhz2-FMHcudtmVieMAsTQ6B8NDByX2NmDr02VTg',
#   'summonerName': 'Yi Zuo Da Shan ',
#   'leaguePoints': 527,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Lb3rxKbvJLkWvmw9sns89nZGlujq8e0eAx4Uj8kbfYv0oSE',
#   'summonerName': 'TTV Potent213',
#   'leaguePoints': 996,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WOolexj5uulpEnQTAPJF0wU4i_opPuS44TDLTYg4H24lximC5yUjULKcOg',
#   'summonerName': 'Nubobo',
#   'leaguePoints': 1174,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'MPw6JI27JlSPeCR8Rc_ruDaNrBaymSPfdAB_bJqg7CpSpYU',
#   'summonerName': 'FUN k3y',
#   'leaguePoints': 701,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ov5FF_mDqukXi-fBIC_Og3VlENZQO0AlSeRmkpdnEoBxYKYyOo7fM9Prog',
#   'summonerName': 'death is equal',
#   'leaguePoints': 555,
#   'rank': 'I',
#   'wins': 155,
#   'losses': 136,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'n-SPcJHzsW_WpitzNBMbDCIwei-NPTtWhjBncPGsInb-04vn',
#   'summonerName': 'Presence0',
#   'leaguePoints': 689,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'yk50H_IWqpxZSuy2w_CiEdI8y8rLCF8sHj3F5ZSCYR6gfhae',
#   'summonerName': 'Twtv Strikelol1',
#   'leaguePoints': 709,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 130,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fpyCsRFSRWgHCF_vU3i5r_qBh41JmX5JazmlI2c9qC3J7us',
#   'summonerName': 'Erdotee',
#   'leaguePoints': 701,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FPu5uSVyIQLbKwuEq2DuUesoMser3YcRCAqet_t96lzww5k',
#   'summonerName': 'Gosu Pepper',
#   'leaguePoints': 674,
#   'rank': 'I',
#   'wins': 159,
#   'losses': 138,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8JiIa0tUNzxfED87XVvIoWCkh8CLCNKo8yMvnyUncix5YIsQT6_mEua-bw',
#   'summonerName': 'Villager C',
#   'leaguePoints': 1313,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '2_jAYiyrxwbJQMvgxlgISAo0i8_jFd5AwtvkYu3SW1lOt3wV',
#   'summonerName': 'Lonely Sunrise',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MBVar5ju0oHIPJLc7LRNta57RP0bMtAwMnDWIv0dFDyRTik4',
#   'summonerName': 'RACHMANINOV',
#   'leaguePoints': 593,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FYmZqpFtzhLdCZDbhsDZca-ZigQTJGE-Zo_ZxvpNKVqqp6I',
#   'summonerName': 'FCB XIXAUXAS',
#   'leaguePoints': 606,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 111,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'TbM8KcIT0CA5WeBm5PRx3-hdKS_k-HG-rfVtIcEXvw_fsl8',
#   'summonerName': 'IAimToMisbehave',
#   'leaguePoints': 537,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'LAZZvwJ8qdUv2PexjwE_fbUP_6_yMIlgHv-BXH1HoZkIm60',
#   'summonerName': 'PCS GotzY',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 125,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'i_KIbsXdhGAgomcqZLao1Baf8DvO-bVf8Q4Okt9X2aJ9stk',
#   'summonerName': 'GIA Stend',
#   'leaguePoints': 530,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Z9ShdyXlbxONmO8WllDtq4TfnOHaQ-WOvuXRqk58J55TJ8M',
#   'summonerName': 'GOREDRINKER HAHA',
#   'leaguePoints': 540,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'GI94jkRe1b7cy5VPoIuv9yYAa7k0c96O_ww2LLR0xVdQ6iA',
#   'summonerName': 'BSC Lamabear',
#   'leaguePoints': 717,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'JHpaoGLdxhVnC9UWWScuW6ZDuPUMgjS9QBzqJFj8gSCgqLvhxmogEfgZBw',
#   'summonerName': 'Final Prince',
#   'leaguePoints': 565,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'cFr4B1JVuoygsLw8RbYuXIJtjYSDYvTWxfnHA4dYyuJHEL4',
#   'summonerName': 'BLACKMETALTERROR',
#   'leaguePoints': 811,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'zgFQ_FOoVhU4ITGxlnpSwRPZG4FY_xCxH4CtOmGVS8eG0ClL',
#   'summonerName': 'RhiIech',
#   'leaguePoints': 581,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 116,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'DKFJNRZCPRa1OY7q6tmRzMaXHNNlT7nJOGM10NNh92p9QGk',
#   'summonerName': 'Zergsting',
#   'leaguePoints': 674,
#   'rank': 'I',
#   'wins': 135,
#   'losses': 118,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kikIdVwUawWFMl4J4bYiVQQE8_XctVjwaYl3lJe_yf4YyPcC',
#   'summonerName': 'je peux changer',
#   'leaguePoints': 699,
#   'rank': 'I',
#   'wins': 145,
#   'losses': 128,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ytnSe36vqTRJXZibK3mGdgcjYufnv7PlIH9O2ooiR9Oj5EM',
#   'summonerName': 'Yung Trizzy',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dE3uxA6TTuQtr2QKLJwTRzMhrTBqJYU_lMTYLjRsbWe_IXQ',
#   'summonerName': 'Reflect',
#   'leaguePoints': 664,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'mQlL6FQAgMn65o-Yv-WWT_3c7isIVKqVAcMa_BeoqV4IfhXyhAGrb2LMGg',
#   'summonerName': 'itzaragoto',
#   'leaguePoints': 628,
#   'rank': 'I',
#   'wins': 155,
#   'losses': 140,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'TRe0hq9b7cLzAAfVVdtppY6smSA7zvOuBQ5fZp1mP4qy',
#   'summonerName': 'LIL AΙan',
#   'leaguePoints': 577,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'GqupXGGxSO5QyxQtgr5hj2dSY7bz8J0aP4033nn_1Sxh4nk',
#   'summonerName': 'yüzenköfte',
#   'leaguePoints': 1177,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 110,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'QEC9uk5NmdUiqqeo37ylE4r7gTnoCARjSqcjgNCJpYVjte6kOKniaVBHlw',
#   'summonerName': 'ZeriFeetAreClean',
#   'leaguePoints': 575,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'iKcYnY-C6HrrtgTMsAaahQBfAYgxml6DSxnUO8RwCcHOV8s',
#   'summonerName': '420WeabooSlayer',
#   'leaguePoints': 579,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GMBYKxRLXAdLc65xwEytB7DTiQt8sP1fHps9ezB0xLwgfMg_',
#   'summonerName': 'Gilius2',
#   'leaguePoints': 558,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'RISdAX38WJOwnJkV0dU0CsJugKmwR8gxgoMXb6o-38g-OETU',
#   'summonerName': 'brokenblade19',
#   'leaguePoints': 833,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '50s8xKfxFq8jriGlpZAtMiXkHjVpxzsPl3PYMYobieg_qZzGDbsEKNHdSw',
#   'summonerName': 'TWTV DETDERT',
#   'leaguePoints': 538,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ywTQb4gvfDwkRmPDioBO7gitTk280kMQmw_JasbyjX7-XsM',
#   'summonerName': 'DMN Shaolin',
#   'leaguePoints': 546,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Afgi0mgIWE9E7pUT-XYRB8EO4FUBOYik39F_565cfSZSAbQ',
#   'summonerName': 'Sebeks',
#   'leaguePoints': 682,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'YD3s8zCr1ufkjVtR9XYzAhJWyyYa9dZsNq-5VGDz7tyED_9bg_F6toAHfA',
# ...
#   'summonerName': 'iDekap',
#   'leaguePoints': 339,
#   'rank': 'I',
#   'wins': 133,
#   'losses': 131,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3zli7d57BsUSQ8LcJXRmeyQNNZ8T0s_AZwRuCw4saZti9Sw',
#   'summonerName': 'Seminol',
#   'leaguePoints': 303,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'z4JY0GscNhfcv8LLlLH-4gS5i-twgvuDKA0T0qycOT8gjrFe_t41OWAZrA',
#   'summonerName': 'V PERKZ',
#   'leaguePoints': 520,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'C3YmopFmtGaKoYCapMckODX8eieiLpp5kM8yHJOMKmo3GzY',
#   'summonerName': 'TanlineTomson',
#   'leaguePoints': 364,
#   'rank': 'I',
#   'wins': 126,
#   'losses': 108,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '7FETTtRnW8MKswUZKnnMqllSuVA3MAdR-G-qVqKjy0ZeA0MJ',
#   'summonerName': 'MADISONBEERFAN23',
#   'leaguePoints': 301,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 78,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bbLoSa4EXuhdeANjkSNDaKDj6Xt_i6mGpt4Pw4i8WwN2X2s',
#   'summonerName': 'KaarlDerAal',
#   'leaguePoints': 411,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'jipMmYiHxM6FsY9pz5a4MAxfQyb6Jbrqj2wt0wMZmUBjo08',
#   'summonerName': 'TwTv Kibbylol',
#   'leaguePoints': 316,
#   'rank': 'I',
#   'wins': 125,
#   'losses': 124,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '7Ic3FaC54Z5sm3aExiULYkXjj_qG_Qb_Byk5FuMuQtwG',
#   'summonerName': 'babi fanboy',
#   'leaguePoints': 401,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '6HsAoggk3KfMpg-gX4x95JDMIrqql5JH2uip8dA0ftGCDlI',
#   'summonerName': 'BADT',
#   'leaguePoints': 374,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cz0OnvJz7u90VedxQrRhtbMzBKVhG99RuxYPF77YANLO1tA',
#   'summonerName': 'Yorick Moris',
#   'leaguePoints': 378,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 80,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'kFdgTPnb4QUdC1OlP6XW2M84X7Igbn7RiSOKDrchByfTHd8B',
#   'summonerName': 'TTVlateroviann99',
#   'leaguePoints': 322,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 130,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'W2NiS7rn4bIb2r0B6BJt7DwhGrvLA7E2DkOXf4Jy60Y4Ctc',
#   'summonerName': 'Svensson',
#   'leaguePoints': 408,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'R7J7fHE1iw5YuEPfK0S2_udozmFi6pAY0KnSuhZpLcbJBhA',
#   'summonerName': 'CHAP PXXL',
#   'leaguePoints': 496,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'KeSsXQVI9lb0q2YZYfc2wGg0tHAmA1IVq5yYJnx1YG5fl1ssV2uAJgYFFw',
#   'summonerName': 'TheSandFeet4',
#   'leaguePoints': 301,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GaNB1juOP8rv1x-Z4TOuK0eNa7xwEyOgfm2JAJjcZu141O8',
#   'summonerName': 'iRoxxzor',
#   'leaguePoints': 334,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'in3dh9U2uvpekhbcBEFD5ye4b-TyuIDPQkOd82jD0MvjA9g',
#   'summonerName': '111111q',
#   'leaguePoints': 454,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'U7kWcNgFiCA4H5__6ukPTSQGU5JxiKx9xEgZ3xplsSPyoFNg',
#   'summonerName': 'Ilyxøu',
#   'leaguePoints': 390,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'blXEk6YJgkElZMaeI6hAHTUltiH5QxWq6jd7r_8WRJsLghgo',
#   'summonerName': 'Nasser3',
#   'leaguePoints': 399,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oqR_ytSJ5y-2EZBlg9_MamUmGnmp6JLqzebDq81M8MNJZpvL',
#   'summonerName': 'uggrot',
#   'leaguePoints': 414,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'QivhTI6qWlw47Zdqtz8sKvUQh8VMtLR_zZqSgZi0-2hnLI6k',
#   'summonerName': 'V eaRyz',
#   'leaguePoints': 304,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-_ThTTnHoO-BGc7pcKtwkChcUwoYJWzBYyn6i50YIZHMSpT3',
#   'summonerName': 'TwTv mephiixlol',
#   'leaguePoints': 468,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'mVdvpYCQKwHkaMoycTyB3XHo6OqlLYyOXdGE06PkYAbgmDU',
#   'summonerName': 'Galáxias',
#   'leaguePoints': 290,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'jnbFpPRLMUv2-JahdZt0e9_ei0QNwnag-gmfazvcbZpo0NfR',
#   'summonerName': 'Myrtus',
#   'leaguePoints': 479,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'V9LniFYMmU93qlTLQpQoLvgER3KKwIiLFdYVpljnBU8pRqU',
#   'summonerName': 'LeIvan',
#   'leaguePoints': 340,
#   'rank': 'I',
#   'wins': 197,
#   'losses': 187,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Es6f-ZprDgef7-n2xZtGmFaWCMIaz47Dq4AkdeJrdwcGXeS_',
#   'summonerName': 'strong mental',
#   'leaguePoints': 301,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'I2dgDlU2q01mprhIbsAxXv-4ZczAPYpGpHVbVg4nDyM4xj8',
#   'summonerName': 'VININE Autophil',
#   'leaguePoints': 433,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'UTyk2WqQkHhWITGpHpM79t7kASNZlO0C07Lt8KqFiqWtoXN1',
#   'summonerName': 'Evewinn',
#   'leaguePoints': 440,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'oRhdumvunSrJSjDVKjmrT8ceKA-APzrbxOJR5BUKbyeYgyW5',
#   'summonerName': 'xia yu le',
#   'leaguePoints': 393,
#   'rank': 'I',
#   'wins': 213,
#   'losses': 202,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '1FjDOLcretVlfi2_WHOZXVSGnW3eJhP-MFLVqc8j66L0FDY',
#   'summonerName': 'chaaz47',
#   'leaguePoints': 402,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'A-rqqdOZnPAUIfGRC_mMxxGzkGXFsCCVLdhugGjv9lYOCq0',
#   'summonerName': 'Supaaa',
#   'leaguePoints': 394,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lXdveiI28ffH1ACIHFKoIsJ8owxCS2BX8TRIBJoNBrHdUcg',
#   'summonerName': 'El Smurfé',
#   'leaguePoints': 359,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'NdBvsdCn3RlZ0KIvA9FyXCBh4B--U29LCvsEMHLPlJ03d_A',
#   'summonerName': 'Emtest',
#   'leaguePoints': 326,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'zi6jfvmldzyMRigL2a4c5ZQm9crCT1qK1TJXvaI3DRGsu6Y',
#   'summonerName': 'Opie',
#   'leaguePoints': 513,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OMUsWWZITFN3lPak5B4MhDzQ0M7FEI2dHDbU3IWB1IOqC_A',
#   'summonerName': 'hdfhdfhdfhdf',
#   'leaguePoints': 342,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'qiL__jkPO8BdTMZ21fHakuYesgtXT3u5g7LRIGRIMcigkDI',
#   'summonerName': 'Take',
#   'leaguePoints': 326,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'QzjLQXmUbLnWqgjZnzN0gbHr8_hPXbfcMaZy8uzt5OOMOlYYPgT7WuoUtw',
#   'summonerName': 'romuka fanboy',
#   'leaguePoints': 459,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'Rj0z18O8UHgnDvINn-1Wvewj7BM8YVS_OE0SqnEWU5TLX1U',
#   'summonerName': 'GER Hunter',
#   'leaguePoints': 322,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lfWKdXy2YijT3wqhO1SNL841O7FxQz7WGLnoWRSdThNA1JOvIedy3S0o_A',
#   'summonerName': 'HATRED 1v9',
#   'leaguePoints': 305,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '_Rj2C_Ifd9x2KKvNm5DhrHiiQDTUC2yzRzmgzeJoYJuukHw',
#   'summonerName': 'A41G Varry',
#   'leaguePoints': 498,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dMSdA5NU0-BEKyP77Z-cgIiRcv87ZTQKFLgSSSv5kOJOdc9ZuNe0Igi2OA',
#   'summonerName': 'WIZ Anonymouss',
#   'leaguePoints': 346,
#   'rank': 'I',
#   'wins': 124,
#   'losses': 118,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'gUXUAyoBqMCXtiJPZ2rztnssrYocnxUsKdzTR3MA4FJyKrw',
#   'summonerName': '7B Eneino',
#   'leaguePoints': 423,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 127,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OYbhBTxa7UsTcZJDhSsPLW0a687ndCM4ctd57z8zOEq6emc',
#   'summonerName': 'GEN Lehends',
#   'leaguePoints': 367,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'M00tnklMEYTofHBXsvzPTsKwbEidSxq4IkM6Tq6vnqG2Qf_G',
#   'summonerName': 'no prio bot',
#   'leaguePoints': 371,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'UPxIG_yeDKkuXjAjx5x7mkH1uHivtn6UPtm9UOrC_BoHYwHbJTAcRQwArQ',
#   'summonerName': 'Secret Weapοn',
#   'leaguePoints': 442,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 128,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'W0P_awcpo-O7pLZNtfflaCza3o01H1xQ6h7pAd08LYxlfuMQ',
#   'summonerName': 'losing my mind',
#   'leaguePoints': 313,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'xiHxOuempaJjFsH4NTfb2nZGwKFcVoTB7YektQzQYyc8tSnU',
#   'summonerName': 'Luv Letter',
#   'leaguePoints': 322,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0GQNRlWyp2Lcgco7w-qr4qvUNt_ih-0gBWTvnymvhXePKYM',
#   'summonerName': 'SLOTH V10',
#   'leaguePoints': 420,
#   'rank': 'I',
#   'wins': 58,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'TeSi1xsoKo4ScTeFV9dJuI0dp8hfsOwQ2Dfuv-lxY3CGx9E',
#   'summonerName': 'Octo Doggo',
#   'leaguePoints': 444,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bSVHn5eaCRdFCmHePHZe7QlDIOWMtxQg5T8vQJq27rpcv88',
#   'summonerName': 'more than everr',
#   'leaguePoints': 443,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Ey5jZU24KtMWEu_VBfTo8AGfjiCqHmvquYcIvpsxF_ou2n4',
#   'summonerName': 'Ayolool',
#   'leaguePoints': 474,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 132,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'saZzJBOas1DpqSWb4TSIGngJYAZ2QYqsstAOMnYlukwte4A',
#   'summonerName': 'HoIyPhoenîx',
#   'leaguePoints': 375,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 106,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'RgyWfbdn8_6yxOJLx2iz0p7WNVnTuZqr_Pd_e9jw2O3mxyc',
#   'summonerName': 'RW Neltran',
#   'leaguePoints': 305,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '-7lMXsqEtVTsH8tSpI3ohYZAPG3aN-YEpaluE_US8r3I7tw',
#   'summonerName': 'ENOUGH IS ENÓUGH',
#   'leaguePoints': 320,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'rEJele-cd3YGAkFthYCkcAwNzc6sNn0i0GV3lvuNIyXFEfY',
#   'summonerName': 'HE Stampe',
#   'leaguePoints': 318,
#   'rank': 'I',
#   'wins': 121,
#   'losses': 116,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'FYsf0iSlC5N2azYWi3mksj7X5QFHFG8XBgRgWoylwmupEco',
#   'summonerName': 'Mίdkίng',
#   'leaguePoints': 347,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Q2DZGn91Csbqa-bVwZ3oXEKDyz1JPsLbPr3h5ecBtY9LywFr',
#   'summonerName': 'PrinceOfThorns',
#   'leaguePoints': 299,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Am3C2wU5HvwlTHK_lhhBZTlrcGYUMRNeqKovZJ6-TnI6dVQf',
#   'summonerName': 'fabees',
#   'leaguePoints': 359,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'PPj9EpSfuDXAfycSU44HWGuPCXeNk7IRWRZ4UJjEe2O1Uj8',
#   'summonerName': 'DMN Sidon',
#   'leaguePoints': 300,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'AxTsV5vYSMnbC273bD3hzmRCpPbG69qhxDhwanI-IMICtbiA',
#   'summonerName': 'HMPeiWan NanBao',
#   'leaguePoints': 559,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 118,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'a0cTvMc0QlDmR91WO1bhQO12Z3e_9pPawqhQfeO1sOhyRpzN',
#   'summonerName': 'ZaZeeeeZaZ',
#   'leaguePoints': 400,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 89,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'QXw6GtZgKeKtkpJZrCkuTDJV3w73EvJnGNsIotqhtf41YZMh',
#   'summonerName': 'RIBU997',
#   'leaguePoints': 458,
#   'rank': 'I',
#   'wins': 165,
#   'losses': 153,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'spspzUp0y_BrlCW7yQ_6uABLbLr7sUuMSeUH09sNWduPX_M',
#   'summonerName': 'The Lοnely God',
#   'leaguePoints': 365,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'F8G9A_yCBx4z9ISl6lYN_tBBfOlMI05DfsOCzoLZV3vU_mQ',
#   'summonerName': 'Peng04',
#   'leaguePoints': 496,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False}]

# %%
summoner_ids = [player['summonerId'] for player in players]

# %%
region = "euw1.api.riotgames.com"
base_endpoint = "/lol/summoner/v4/summoners/"

players_full = []

for i, summoner_id in enumerate(summoner_ids):
    URL = region + base_endpoint + summoner_id + "/"
    
    results = riot_api(URL, creds['key_one'])
    
    time.sleep(0.85) # put in some sleep time to avoid hitting rate limits
    
    if i % 100 == 0:
        print(f'{i} requests made')
    
    players_full.append(results)
# Out:
# 0 requests made
# 100 requests made
# 200 requests made
# 300 requests made
# 400 requests made
# 500 requests made
# 600 requests made
# 700 requests made
# 800 requests made
# 900 requests made

# %%
# so that we don't lose this data (and have to call the APIs again, let's save this data to file)

players_df = pd.DataFrame(players_full)
players_df.to_csv('players.csv', index=False)

# %%
# this cell was run twice with the second the the all_matches was commented out
#all_matches = set([])


for i, puuid in enumerate(list(players_df['puuid'].values)):
    endpoint = '/lol/match/v5/matches/by-puuid/' + puuid +  '/ids'
    
    # we chose count=70 variable to account for some overlap of games, we are aiming for 50games/player
    matches_list =  riot_api(europe + endpoint, creds['key_one'] + "&type=ranked&start=70&count=70")
    
    [all_matches.add(item) for item in matches_list]
    
    time.sleep(0.85)
    
    if i % 100 == 0:
        print(f'{i} requests made')
    
# again save to remove chance of losing data!
matches = pd.DataFrame(list(all_matches), columns=['Matches'])
matches.to_csv('matches_2.csv')
# Out:
# 0 requests made
# 100 requests made
# 200 requests made
# 300 requests made
# 400 requests made
# 500 requests made
# 600 requests made
# 700 requests made
# 800 requests made
# 900 requests made

# %%
# check how many matches we have in total (a max of 70,000 given no overlap)
print(matches.shape) 

# only 22,800 matches with parameters of 70 games / api call. Means a high degree of game overlap. 
# Let us take 70 more by changing above cell parameters to start=70, count=70 (from start=0)
# Out:
# (22866, 1)

# %%
print(matches.shape)
# Out:
# (52155, 1)

# %%
# step 2: call data and save to file every 1000 calls for timeline + summary data

save_file_summaries = './match-data/summaries/'
save_file_timeline = './match-data/timelines/'

# another loop here to save files - but first test inside loop

for j in range(18000,matches.shape[0],1000):

    match_summary_data = []
    match_timeline_data = []

    for i, match in enumerate(matches['Matches'].values[j:j+1000]):

        a = time.time()

        one_match_endpoint = '/lol/match/v5/matches/' + match
        one_match_data = riot_api(europe + one_match_endpoint, creds['key_one'])
        two_match_data = riot_api(europe + one_match_endpoint, creds['key_two'])

        timeline_endpoint = f'/lol/match/v5/matches/{match}/timeline'
        three_timeline_data = riot_api(europe + timeline_endpoint, creds['key_three'])
        four_timeline_data = riot_api(europe + timeline_endpoint, creds['key_four'])

        match_summary_data = match_summary_data + [one_match_data] + [two_match_data]
        match_timeline_data = match_timeline_data + [three_timeline_data] + [four_timeline_data]

        b = time.time()

        # add in rate-limiting if necessary
        if b-a < 0.85:
            remainder = 0.85 - (b-a)
            time.sleep(remainder)
            
        if i % 100 == 0:
            print(str(j+i) +  ' requests made')

    timeline_path = save_file_timeline + 'timeline_' + str(j) + '.csv'
    summary_path = save_file_summaries + 'summary_' + str(j) + '.csv'
    
    timeline_df = pd.DataFrame(match_timeline_data)
    timeline_df.to_csv(timeline_path, index=False)

    summary_df = pd.DataFrame(match_summary_data)
    summary_df.to_csv(summary_path, index=False)

# some save to a dataframe here and save that to a file containing some index value every 1000 runs
# spotted a bug in here - each datapoint should be duplicated exactly once - will deduplicate later
# Out:
# 18000 requests made
# 18100 requests made
# 18200 requests made
# 18300 requests made
# 18400 requests made
# 18500 requests made
# 18600 requests made
# 18700 requests made
# 18800 requests made
# 18900 requests made
# 19000 requests made
# 19100 requests made
# 19200 requests made
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-0da7e59c2b91> in <module>
#      20
#      21         timeline_endpoint = f'/lol/match/v5/matches/{match}/timeline'
# ---> 22         three_timeline_data = riot_api(europe + timeline_endpoint, creds['key_three'])
#      23         four_timeline_data = riot_api(europe + timeline_endpoint, creds['key_four'])
#      24
#
# <ipython-input-11-ef3537745436> in riot_api(api, api_key)
#       5     URL = 'https://' + api + "?api_key=" + api_key
#       6
# ----> 7     response = requests.get(URL)
#       8
#       9     return response.json()
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ## ----- Manually Interrupted -----
#
# ## 1000 timeline match data sets are 1GB large each, summary data is 65mb. Download continuing anyway but this will push the limit of a local-only setup. (~60GB data in total)
# ## Time considerations mean it won't realistically be possible to deploy the data + compute resources to the cloud
#
# ## after collecting 20gb of timeline data, due to time constraints, the decision was made to continue to collect 50,000 games of only summary data to speed up the data collection process

# %%
# run the same script with only timeline data

# step 2: call data and save to file every 1000 calls

save_file_summaries = './match-data/summaries/'
save_file_timeline = './match-data/timelines/'

# another loop here to save files - but first test inside loop

for j in range(37000,matches.shape[0],1000):

    match_summary_data = []

    
    for i in range(j, j+1000, 4):
        
        a = time.time()
        
        match_endpoint_1 = '/lol/match/v5/matches/' + matches['Matches'].values[i]
        match_endpoint_2 = '/lol/match/v5/matches/' + matches['Matches'].values[i+1]
        match_endpoint_3 = '/lol/match/v5/matches/' + matches['Matches'].values[i+2]
        match_endpoint_4 = '/lol/match/v5/matches/' + matches['Matches'].values[i+3]
        
        match_data_1 = riot_api(europe + match_endpoint_1, creds['key_one'])
        match_data_2 = riot_api(europe + match_endpoint_2, creds['key_two'])
        match_data_3 = riot_api(europe + match_endpoint_3, creds['key_three'])
        match_data_4 = riot_api(europe + match_endpoint_4, creds['key_four'])
        

        match_summary_data = match_summary_data + [match_data_1] + \
                            [match_data_2] + [match_data_3] + [match_data_4]
        
        b = time.time()
        
        # add in rate-limiting if necessary
        if b-a < 0.85:
            remainder = 0.85 - (b-a)
            time.sleep(remainder)
            
        # keep track of progress
        if i % 100 == 0:
            print(str(i) +  ' requests made')

            
    summary_path = save_file_summaries + 'summary_' + str(j) + '.csv'
    summary_df = pd.DataFrame(match_summary_data)
    summary_df.to_csv(summary_path, index=False)
# Out:
# 37000 requests made
# 37100 requests made
# 37200 requests made
# 37300 requests made
# 37400 requests made
# 37500 requests made
# 37600 requests made
# 37700 requests made
# 37800 requests made
# 37900 requests made
# 38000 requests made
# 38100 requests made
# 38200 requests made
# 38300 requests made
# 38400 requests made
# 38500 requests made
# 38600 requests made
# 38700 requests made
# 38800 requests made
# 38900 requests made
# 39000 requests made
# 39100 requests made
# 39200 requests made
# 39300 requests made
# 39400 requests made
# 39500 requests made
# 39600 requests made
# 39700 requests made
# 39800 requests made
# 39900 requests made
# 40000 requests made
# 40100 requests made
# 40200 requests made
# 40300 requests made
# 40400 requests made
# 40500 requests made
# 40600 requests made
# 40700 requests made
# 40800 requests made
# 40900 requests made
# 41000 requests made
# 41100 requests made
# 41200 requests made
# 41300 requests made
# 41400 requests made
# 41500 requests made
# 41600 requests made
# 41700 requests made
# 41800 requests made
# 41900 requests made
# 42000 requests made
# 42100 requests made
# 42200 requests made
# 42300 requests made
# 42400 requests made
# 42500 requests made
# 42600 requests made
# 42700 requests made
# 42800 requests made
# 42900 requests made
# 43000 requests made
# 43100 requests made
# 43200 requests made
# 43300 requests made
# 43400 requests made
# 43500 requests made
# 43600 requests made
# 43700 requests made
# 43800 requests made
# 43900 requests made
# 44000 requests made
# 44100 requests made
# 44200 requests made
# 44300 requests made
# 44400 requests made
# 44500 requests made
# 44600 requests made
# 44700 requests made
# 44800 requests made
# 44900 requests made
# 45000 requests made
# 45100 requests made
# 45200 requests made
# 45300 requests made
# 45400 requests made
# 45500 requests made
# 45600 requests made
# 45700 requests made
# 45800 requests made
# 45900 requests made
# 46000 requests made
# 46100 requests made
# 46200 requests made
# 46300 requests made
# 46400 requests made
# 46500 requests made
# 46600 requests made
# 46700 requests made
# 46800 requests made
# 46900 requests made
# 47000 requests made
# 47100 requests made
# 47200 requests made
# 47300 requests made
# 47400 requests made
# 47500 requests made
# 47600 requests made
# 47700 requests made
# 47800 requests made
# 47900 requests made
# 48000 requests made
# 48100 requests made
# 48200 requests made
# 48300 requests made
# 48400 requests made
# 48500 requests made
# 48600 requests made
# 48700 requests made
# 48800 requests made
# 48900 requests made
# 49000 requests made
# 49100 requests made
# 49200 requests made
# 49300 requests made
# 49400 requests made
# 49500 requests made
# 49600 requests made
# 49700 requests made
# 49800 requests made
# 49900 requests made
# 50000 requests made
# 50100 requests made
# 50200 requests made
# 50300 requests made
# 50400 requests made
# 50500 requests made
# 50600 requests made
# 50700 requests made
# 50800 requests made
# 50900 requests made
# 51000 requests made
# 51100 requests made
# 51200 requests made
# 51300 requests made
# 51400 requests made
# 51500 requests made
# 51600 requests made
# 51700 requests made
# 51800 requests made
# 51900 requests made
# 52000 requests made
# 52100 requests made
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-199-74be1cb4c346> in <module>
#      20         match_endpoint_2 = '/lol/match/v5/matches/' + matches['Matches'].values[i+1]
#      21         match_endpoint_3 = '/lol/match/v5/matches/' + matches['Matches'].values[i+2]
# ---> 22         match_endpoint_4 = '/lol/match/v5/matches/' + matches['Matches'].values[i+3]
#      23
#      24         match_data_1 = riot_api(europe + match_endpoint_1, creds['key_one'])
#
# IndexError: index 52155 is out of bounds for axis 0 with size 52155

# %%
# finished collecting! (in a very dirty way - but time is of the essence)
